# %% [markdown]
# > Der Kernel dieses Notebooks sollte nicht neu gestartet werden, da sonst die Auswertungen der einzenen Abschnitte nicht mehr stimmen. Am Ende des Notebooks wird es aber eine Lösung dieses Problems geben.

# %% [markdown]
# # Twitter Mining
#
# ## Einstieg: Was ist Twitter
#
# Twitter ist ein Social Network, wo angemeldete Nutzer Kurznachrichten (Tweets) verbreiten können. Bis vor kurzem war die maximale Länge der Tweets 140 Zeichen, neuerdings können die Tweets die doppelte Zeichenlänge betragen. Diese Tweets können favorisiert, geteilt (retweet) oder auch mit einem eigenen Tweet kommentiert werden.
# Tweets können auf andere User verweisen (@username), Bilder, Links und Standorte können geteilt werden, und Hashtags (#) können genutzt werden. Nach diesen Hashtags kann auf der gesamten Website gesucht werden, wodurch regen Diskussionen eine Plattform geboten wird.
#
# ## API
#
# Eine Programmierschnittstelle (kurz: API) ist ein Programmteil, der von einem Softwaresystem anderen Programmen zur Anbindung an das System zur Verfügung gestellt wird. Sie dient dazu, Informationen zwischen einer Anwendung und einzelnen Programmteilen standardisiert auszutauschen. Die Übergabe von Daten und Befehlen erfolgt strukturiert nach einer zuvor definierten Syntax. Die Kommunikation von einzelnen Programmmodulen ist lediglich über die genau spezifizierte Schnittstelle möglich. Die Twitter-API erlaubt die Integration von Twitter in andere Anwendungen und Websites.
#
# ### Python-Package: Twitter
#
# Auch in Python gibt es ein Package, dass die Twitter-API verpackt und die öffentliche API-Semantik fast 1-zu-1 imitiert. Dieses Package heißt *Twitter*.
# Dieses kann, wie andere Packages, mithilfe von pip installiert werden.
# Dazu muss zunächst die cmd.exe geöffnet werden und mittels cmd-Befehlen (cd) auf das Verzeichnis ...\Anaconda3\Scripts gewechselt werden, wo dann `pip install twitter` eingegeben werden muss. Nach Drücken der Enter-Taste wird das package installiert und man kann anfangen Twitter Mining mit Python zu betreiben.
#
# Da wir in der Vorlesung Anaconda benutzen, lässt sich das Package noch einfacher installieren, indem man *Anaconda Prompt* öffnet und auch hier `pip install` benutzt.
#
# Um die Twitter-Bibliothek in unserem JupyterNotebook nutzen zu können müssen wir sie zunächst importieren.

# %% [markdown]
# # <span style="color:red">Kommentar JI</span>
#  Eventuell "komplizierte" Installation über cmd weg lassen oder zuerst einfache Version über Anaconda Prompt erklären, damit Leser nicht gleich verschreckt wird

# %%
import twitter

# %% [markdown]
# Als nächstes können wir uns die Dokumentation unserer Bibliothek anschauen.

# %%
twitter?

# %% [markdown]
# # <span style="color:red">Kommentar JI</span>
# Was passiert hier? Wo ist die Dokumentation?

# %% [markdown]
# ## Application
#
# Bevor man irgendwelche API-Anfragen an Twitter stellen kann, muss man zunächst einen Twitter-Account erstellen. Dieser wird benötigt, um eine Application auf https://apps.twitter.com/ zu erstellen. Eine Application zu erstellen ist der übliche Weg eines Entwicklers, um Zugriff auf die API zu erhalten. Alles, was wir brauchen, ist ein Lese-und-Schreib-Zugriff.
#
# ### Autentifizierung
#
# Für die Autentifizierung der eigenen Application gibt es ein standardisiertes Protokoll **OAuth** (kurz für *Open Authorization*), das es Benutzern erlaubt, Anwendungen von Drittanbietern zu autorisieren, um auf ihre Kontodaten zuzugreifen, ohne dass sensible Informationen, wie Passwörter, ausgetauscht werden müssen.
# Wir benötigen deshalb  den `consumer key`, das `consumer secret`, den `access token`, und das `access token secret` unserer neu erstellten Twitter-Aplication.
#
# ![Consumer key und consumer secret](https://i.imgur.com/qcTliap.jpg "Consumer key und consumer secret")
# ![Access token und access token secret](https://i.imgur.com/I5tMx9d.jpg "Access token und access token secret")
#
# Nun fangen wir an, und starten eine authentifizierte Verbindung zur Twitter-API, indem wir zunächst unsere Variablen füllen.

# %%
CONSUMER_KEY = 'v6hhWSLggZvhqFZr6fFtbO7t1'
CONSUMER_SECRET = 'pNLQCcbUDIsPXfw7TWzlSCJQ1kcswk4SW1lZOWL8Yiqe6jr8qU'
OAUTH_TOKEN = '168648836-atEdUT3jeyWtCq1xQL2JhsrQQTCUEcmfxEamdsZ4' 
OAUTH_TOKEN_SECRET = 'ASJ31Q9vW1eKpZxjlyz364pqBtoFQItimexlvF5V7wF22'

# %% [markdown]
# Dabei legen wir ein Objekt `auth` an mit unseren OAuth-Referenzen, dass unsere OAuth-Authentifizierung darstellt und das wir an unsere Klasse Twitter weitergeben, um Anfragen an Twitters API zu stellen.

# %%
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# ## Twitter erforschen
#
#
# ### Trends untersuchen
#
# In Twitter werden die aktuellen Trends in einer Region angezeigt. Wird über ein bestimmtes Thema, wie beispielsweise ein Bundesligaspiel, viel getwittert, wird es in die Trends aufgenommen und auf der Timeline am Rand aufgelistet. Diese Trends unterschieden sich je nach dem, welchen Ort man ausgewählt hat.
#
# Um die Trends von verschiedenen Standorten zu betrachten, benutzen wir [Yahoo! GeoPlanet’s] Where On Earth (WOE) ID System.
# Die WOEID für die ganze Welt ist 1, Deutschland hat die ID 23424829.
#
# [Yahoo! GeoPlanet’s]: http://www.woeidlookup.com/

# %%
WW_WOE_ID = 1
D_WOE_ID = 23424829

ww_trends = twitter_api.trends.place(_id=WW_WOE_ID)
d_trends = twitter_api.trends.place(_id=D_WOE_ID)

print(ww_trends)
print ()
print(d_trends)
# Out:
# [{'trends': [{'name': '#السينما_في_السعوديه', 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B3%D9%8A%D9%86%D9%85%D8%A7_%D9%81%D9%8A_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87', 'promoted_content': None, 'query': '%23%D8%A7%D9%84%D8%B3%D9%8A%D9%86%D9%85%D8%A7_%D9%81%D9%8A_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87', 'tweet_volume': 39562}, {'name': '#FelizLunes', 'url': 'http://twitter.com/search?q=%23FelizLunes', 'promoted_content': None, 'query': '%23FelizLunes', 'tweet_volume': None}, {'name': '#اشهر_ماقيل_في_الحب', 'url': 'http://twitter.com/search?q=%23%D8%A7%D8%B4%D9%87%D8%B1_%D9%85%D8%A7%D9%82%D9%8A%D9%84_%D9%81%D9%8A_%D8%A7%D9%84%D8%AD%D8%A8', 'promoted_content': None, 'query': '%23%D8%A7%D8%B4%D9%87%D8%B1_%D9%85%D8%A7%D9%82%D9%8A%D9%84_%D9%81%D9%8A_%D8%A7%D9%84%D8%AD%D8%A8', 'tweet_volume': 70782}, {'name': 'Sijena', 'url': 'http://twitter.com/search?q=Sijena', 'promoted_content': None, 'query': 'Sijena', 'tweet_volume': 17414}, {'name': '#TheWalkingDead', 'url': 'http://twitter.com/search?q=%23TheWalkingDead', 'promoted_content': None, 'query': '%23TheWalkingDead', 'tweet_volume': 189614}, {'name': '#HeartShaker', 'url': 'http://twitter.com/search?q=%23HeartShaker', 'promoted_content': None, 'query': '%23HeartShaker', 'tweet_volume': 55854}, {'name': 'Nazlı Ilıcak', 'url': 'http://twitter.com/search?q=%22Nazl%C4%B1+Il%C4%B1cak%22', 'promoted_content': None, 'query': '%22Nazl%C4%B1+Il%C4%B1cak%22', 'tweet_volume': None}, {'name': 'İTO Başkanı İbrahim Çağlar', 'url': 'http://twitter.com/search?q=%22%C4%B0TO+Ba%C5%9Fkan%C4%B1+%C4%B0brahim+%C3%87a%C4%9Flar%22', 'promoted_content': None, 'query': '%22%C4%B0TO+Ba%C5%9Fkan%C4%B1+%C4%B0brahim+%C3%87a%C4%9Flar%22', 'tweet_volume': None}, {'name': 'Cat Person', 'url': 'http://twitter.com/search?q=%22Cat+Person%22', 'promoted_content': None, 'query': '%22Cat+Person%22', 'tweet_volume': 18167}, {'name': '주의보', 'url': 'http://twitter.com/search?q=%EC%A3%BC%EC%9D%98%EB%B3%B4', 'promoted_content': None, 'query': '%EC%A3%BC%EC%9D%98%EB%B3%B4', 'tweet_volume': None}, {'name': "B'z人生ゲーム", 'url': 'http://twitter.com/search?q=B%27z%E4%BA%BA%E7%94%9F%E3%82%B2%E3%83%BC%E3%83%A0', 'promoted_content': None, 'query': 'B%27z%E4%BA%BA%E7%94%9F%E3%82%B2%E3%83%BC%E3%83%A0', 'tweet_volume': None}, {'name': 'Türkiye 3', 'url': 'http://twitter.com/search?q=%22T%C3%BCrkiye+3%22', 'promoted_content': None, 'query': '%22T%C3%BCrkiye+3%22', 'tweet_volume': None}, {'name': 'Milica van Doorn', 'url': 'http://twitter.com/search?q=%22Milica+van+Doorn%22', 'promoted_content': None, 'query': '%22Milica+van+Doorn%22', 'tweet_volume': None}, {'name': "Suudi Arabistan'da", 'url': 'http://twitter.com/search?q=%22Suudi+Arabistan%27da%22', 'promoted_content': None, 'query': '%22Suudi+Arabistan%27da%22', 'tweet_volume': None}, {'name': '#pazartesi', 'url': 'http://twitter.com/search?q=%23pazartesi', 'promoted_content': None, 'query': '%23pazartesi', 'tweet_volume': 10616}, {'name': '#AdileNaşit', 'url': 'http://twitter.com/search?q=%23AdileNa%C5%9Fit', 'promoted_content': None, 'query': '%23AdileNa%C5%9Fit', 'tweet_volume': None}, {'name': '#المتعه_ب', 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D9%85%D8%AA%D8%B9%D9%87_%D8%A8', 'promoted_content': None, 'query': '%23%D8%A7%D9%84%D9%85%D8%AA%D8%B9%D9%87_%D8%A8', 'tweet_volume': 25166}, {'name': '#OTDirecto11D', 'url': 'http://twitter.com/search?q=%23OTDirecto11D', 'promoted_content': None, 'query': '%23OTDirecto11D', 'tweet_volume': None}, {'name': '#Sixena', 'url': 'http://twitter.com/search?q=%23Sixena', 'promoted_content': None, 'query': '%23Sixena', 'tweet_volume': 10713}, {'name': '#11dicembre', 'url': 'http://twitter.com/search?q=%2311dicembre', 'promoted_content': None, 'query': '%2311dicembre', 'tweet_volume': None}, {'name': '#MondayMotivaton', 'url': 'http://twitter.com/search?q=%23MondayMotivaton', 'promoted_content': None, 'query': '%23MondayMotivaton', 'tweet_volume': None}, {'name': '#InternationalMountainDay', 'url': 'http: ...
#
# [{'trends': [{'name': '#MondayMotivation', 'url': 'http://twitter.com/search?q=%23MondayMotivation', 'promoted_content': None, 'query': '%23MondayMotivation', 'tweet_volume': 25862}, {'name': 'Start in die Woche', 'url': 'http://twitter.com/search?q=%22Start+in+die+Woche%22', 'promoted_content': None, 'query': '%22Start+in+die+Woche%22', 'tweet_volume': None}, {'name': 'Montagmorgen', 'url': 'http://twitter.com/search?q=Montagmorgen', 'promoted_content': None, 'query': 'Montagmorgen', 'tweet_volume': None}, {'name': '#TheWalkingDead', 'url': 'http://twitter.com/search?q=%23TheWalkingDead', 'promoted_content': None, 'query': '%23TheWalkingDead', 'tweet_volume': 189415}, {'name': '#Montagslaecheln', 'url': 'http://twitter.com/search?q=%23Montagslaecheln', 'promoted_content': None, 'query': '%23Montagslaecheln', 'tweet_volume': None}, {'name': '#Krimi', 'url': 'http://twitter.com/search?q=%23Krimi', 'promoted_content': None, 'query': '%23Krimi', 'tweet_volume': None}, {'name': 'Waffen', 'url': 'http://twitter.com/search?q=Waffen', 'promoted_content': None, 'query': 'Waffen', 'tweet_volume': None}, {'name': '#KOESCF', 'url': 'http://twitter.com/search?q=%23KOESCF', 'promoted_content': None, 'query': '%23KOESCF', 'tweet_volume': None}, {'name': 'Schnee', 'url': 'http://twitter.com/search?q=Schnee', 'promoted_content': None, 'query': 'Schnee', 'tweet_volume': 21957}, {'name': 'Köln', 'url': 'http://twitter.com/search?q=K%C3%B6ln', 'promoted_content': None, 'query': 'K%C3%B6ln', 'tweet_volume': 13699}, {'name': 'Halbzeit', 'url': 'http://twitter.com/search?q=Halbzeit', 'promoted_content': None, 'query': 'Halbzeit', 'tweet_volume': None}, {'name': '#Tatort', 'url': 'http://twitter.com/search?q=%23Tatort', 'promoted_content': None, 'query': '%23Tatort', 'tweet_volume': None}, {'name': '#Stöger', 'url': 'http://twitter.com/search?q=%23St%C3%B6ger', 'promoted_content': None, 'query': '%23St%C3%B6ger', 'tweet_volume': None}, {'name': '#schwiegertochtergesucht', 'url': 'http://twitter.com/search?q=%23schwiegertochtergesucht', 'promoted_content': None, 'query': '%23schwiegertochtergesucht', 'tweet_volume': None}, {'name': '#bvbsvw', 'url': 'http://twitter.com/search?q=%23bvbsvw', 'promoted_content': None, 'query': '%23bvbsvw', 'tweet_volume': None}, {'name': '#H96TSG', 'url': 'http://twitter.com/search?q=%23H96TSG', 'promoted_content': None, 'query': '%23H96TSG', 'tweet_volume': None}, {'name': '#TagderMenschenrechte', 'url': 'http://twitter.com/search?q=%23TagderMenschenrechte', 'promoted_content': None, 'query': '%23TagderMenschenrechte', 'tweet_volume': None}, {'name': '#AnneWill', 'url': 'http://twitter.com/search?q=%23AnneWill', 'promoted_content': None, 'query': '%23AnneWill', 'tweet_volume': None}, {'name': '#HumanRightsDay', 'url': 'http://twitter.com/search?q=%23HumanRightsDay', 'promoted_content': None, 'query': '%23HumanRightsDay', 'tweet_volume': 176658}, {'name': '#ranNFL', 'url': 'http://twitter.com/search?q=%23ranNFL', 'promoted_content': None, 'query': '%23ranNFL', 'tweet_volume': None}, {'name': '#fcspmsv', 'url': 'http://twitter.com/search?q=%23fcspmsv', 'promoted_content': None, 'query': '%23fcspmsv', 'tweet_volume': None}, {'name': '#SEAvsJAX', 'url': 'http://twitter.com/search?q=%23SEAvsJAX', 'promoted_content': None, 'query': '%23SEAvsJAX', 'tweet_volume': 18362}, {'name': '#FCKFCI', 'url': 'http://twitter.com/search?q=%23FCKFCI', 'promoted_content': None, 'query': '%23FCKFCI', 'tweet_volume': None}, {'name': '#KitchenImpossible', 'url': 'http://twitter.com/search?q=%23KitchenImpossible', 'promoted_content': None, 'query': '%23KitchenImpossible', 'tweet_volume': None}, {'name': '#HadeB', 'url': 'http://twitter.com/search?q=%23HadeB', 'promoted_content': None, 'query': '%23HadeB', 'tweet_volume': None}, {'name': '#CWLDallas', 'url': 'http://twitter.com/search?q=%23CWLDallas', 'promoted_content': None, 'query': '%23CWLDallas', 'tweet_volume': 18184}, {'name': '#GERDEN', 'url': 'http://twitter.com/search?q=%23GERDEN', 'pr ...

# %% [markdown]
# Wie wir sehen können, ist die Ausgabe ziemlich unübersichtlich. Um das ganze schöner darzustellen, werden wir die `json` Bibliothek benutzen.
#
# Json ist ein weitverbreitetes Datenaustauschformat. Es ermöglicht es beliebige Karten, Listen, Zahlen, sowie auch Strings und Kombinationen dieser zu speichern. Bei JSON handelt es sich um ein Textformat, das komplett unabhängig von Programmiersprachen ist, aber vielen Konventionen folgt, die Programmieren (C, C++, C#, Java, JavaScript und auch Python) bekannt ist. Diese Eigenschaften machen JSON zum idealen Format für Datenaustausch.
#
# Um unser Ergebnis schön darzustellen genügt es, folgendes zu tun:

# %%
import json

print (json.dumps(ww_trends, indent=1))
print()
print(json.dumps(d_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#\u0627\u0644\u0633\u064a\u0646\u0645\u0627_\u0641\u064a_\u0627\u0644\u0633\u0639\u0648\u062f\u064a\u0647",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B3%D9%8A%D9%86%D9%85%D8%A7_%D9%81%D9%8A_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%B3%D9%8A%D9%86%D9%85%D8%A7_%D9%81%D9%8A_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87",
#     "tweet_volume": 39562
#    },
#    {
#     "name": "#FelizLunes",
#     "url": "http://twitter.com/search?q=%23FelizLunes",
#     "promoted_content": null,
#     "query": "%23FelizLunes",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0627\u0634\u0647\u0631_\u0645\u0627\u0642\u064a\u0644_\u0641\u064a_\u0627\u0644\u062d\u0628",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D8%B4%D9%87%D8%B1_%D9%85%D8%A7%D9%82%D9%8A%D9%84_%D9%81%D9%8A_%D8%A7%D9%84%D8%AD%D8%A8",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D8%B4%D9%87%D8%B1_%D9%85%D8%A7%D9%82%D9%8A%D9%84_%D9%81%D9%8A_%D8%A7%D9%84%D8%AD%D8%A8",
#     "tweet_volume": 70782
#    },
#    {
#     "name": "Sijena",
#     "url": "http://twitter.com/search?q=Sijena",
#     "promoted_content": null,
#     "query": "Sijena",
#     "tweet_volume": 17414
#    },
#    {
#     "name": "#TheWalkingDead",
#     "url": "http://twitter.com/search?q=%23TheWalkingDead",
#     "promoted_content": null,
#     "query": "%23TheWalkingDead",
#     "tweet_volume": 189614
#    },
#    {
#     "name": "#HeartShaker",
#     "url": "http://twitter.com/search?q=%23HeartShaker",
#     "promoted_content": null,
#     "query": "%23HeartShaker",
#     "tweet_volume": 55854
#    },
#    {
#     "name": "Nazl\u0131 Il\u0131cak",
#     "url": "http://twitter.com/search?q=%22Nazl%C4%B1+Il%C4%B1cak%22",
#     "promoted_content": null,
#     "query": "%22Nazl%C4%B1+Il%C4%B1cak%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "\u0130TO Ba\u015fkan\u0131 \u0130brahim \u00c7a\u011flar",
#     "url": "http://twitter.com/search?q=%22%C4%B0TO+Ba%C5%9Fkan%C4%B1+%C4%B0brahim+%C3%87a%C4%9Flar%22",
#     "promoted_content": null,
#     "query": "%22%C4%B0TO+Ba%C5%9Fkan%C4%B1+%C4%B0brahim+%C3%87a%C4%9Flar%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Cat Person",
#     "url": "http://twitter.com/search?q=%22Cat+Person%22",
#     "promoted_content": null,
#     "query": "%22Cat+Person%22",
#     "tweet_volume": 18167
#    },
#    {
#     "name": "\uc8fc\uc758\ubcf4",
#     "url": "http://twitter.com/search?q=%EC%A3%BC%EC%9D%98%EB%B3%B4",
#     "promoted_content": null,
#     "query": "%EC%A3%BC%EC%9D%98%EB%B3%B4",
#     "tweet_volume": null
#    },
#    {
#     "name": "B'z\u4eba\u751f\u30b2\u30fc\u30e0",
#     "url": "http://twitter.com/search?q=B%27z%E4%BA%BA%E7%94%9F%E3%82%B2%E3%83%BC%E3%83%A0",
#     "promoted_content": null,
#     "query": "B%27z%E4%BA%BA%E7%94%9F%E3%82%B2%E3%83%BC%E3%83%A0",
#     "tweet_volume": null
#    },
#    {
#     "name": "T\u00fcrkiye 3",
#     "url": "http://twitter.com/search?q=%22T%C3%BCrkiye+3%22",
#     "promoted_content": null,
#     "query": "%22T%C3%BCrkiye+3%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Milica van Doorn",
#     "url": "http://twitter.com/search?q=%22Milica+van+Doorn%22",
#     "promoted_content": null,
#     "query": "%22Milica+van+Doorn%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Suudi Arabistan'da",
#     "url": "http://twitter.com/search?q=%22Suudi+Arabistan%27da%22",
#     "promoted_content": null,
#     "query": "%22Suudi+Arabistan%27da%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#pazartesi",
#     "url": "http://twitter.com/search?q=%23pazartesi",
#     "promoted_content": null,
#     "query": "%23pazartesi",
#     "tweet_volume": 10616
#    },
#    {
#     "name": "#AdileNa\u015fit",
#     "url": "http://twitter.com/search?q=%23AdileNa%C5%9Fit",
#     "promoted_content": null,
#     "query": "%23AdileNa%C5%9Fit",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0627\u0644\u0645\u062a\u0639\u0647_\u0628",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D9%85%D8%AA%D8%B9%D9%87_%D8%A8",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D9%85%D8%AA%D8%B9%D9%87_%D8%A8",
#     "tweet_volume": 25166
#    },
#    {
#     "name": "#OTDirecto11D",
#     "url": "http://twitter.com/search?q=%23OTDirecto11D",
#     "promoted_content": null,
#     "query": "%23OTDirecto11D",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Sixena",
#     "url": "http://twitter.com/search?q=%23Sixena",
#     "promoted_content": null,
#     "query": "%23Sixena",
#     "tweet_volume": 10713
#    },
#    {
#     "name": "#11dicembre",
#     "url": "http://twitter.com/search?q=%2311dicembre",
#     "promoted_content": null,
#     "query": "%2311dicembre",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MondayMotivaton",
#     "url": "http://twitter.com/search?q=%23MondayMotivaton",
#     "promoted_content": null,
#     "query": "%23MondayMotivaton",
#     "tweet_volume": null
#    },
#    {
#     "name": "#InternationalMountainDay",
#     "url": "http://twitter.com/search?q=%23InternationalMountainDay",
#     "promoted_content": null,
#     "query": "%23InternationalMountainDay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#OnePlanetSummit",
#     "url": "http://twitter.com/search?q=%23OnePlanetSummit",
#     "promoted_content": null,
#     "query": "%23OnePlanetSummit",
#     "tweet_volume": null
#    },
#    {
#     "name": "#UCLDraw",
#     "url": "http://twitter.com/search?q=%23UCLDraw",
#     "promoted_content": null,
#     "query": "%23UCLDraw",
#     "tweet_volume": null
#    },
#    {
#     "name": "#EPDesayunoRajoy",
#     "url": "http://twitter.com/search?q=%23EPDesayunoRajoy",
#     "promoted_content": null,
#     "query": "%23EPDesayunoRajoy",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HappyBirthdayDilipKumar",
#     "url": "http://twitter.com/search?q=%23HappyBirthdayDilipKumar",
#     "promoted_content": null,
#     "query": "%23HappyBirthdayDilipKumar",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\uc790\uce90\ub4e4\uc774_\ubaa8\uc5ec\uc788\ub294\ub370_\uac15\ub3c4\uac00_\ub4e0\ub2e4\uba74",
#     "url": "http://twitter.com/search?q=%23%EC%9E%90%EC%BA%90%EB%93%A4%EC%9D%B4_%EB%AA%A8%EC%97%AC%EC%9E%88%EB%8A%94%EB%8D%B0_%EA%B0%95%EB%8F%84%EA%B0%80_%EB%93%A0%EB%8B%A4%EB%A9%B4",
#     "promoted_content": null,
#     "query": "%23%EC%9E%90%EC%BA%90%EB%93%A4%EC%9D%B4_%EB%AA%A8%EC%97%AC%EC%9E%88%EB%8A%94%EB%8D%B0_%EA%B0%95%EB%8F%84%EA%B0%80_%EB%93%A0%EB%8B%A4%EB%A9%B4",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0130nsanl\u0131k\u0130\u00e7in\u0130yikiVars\u0131n\u0131z",
#     "url": "http://twitter.com/search?q=%23%C4%B0nsanl%C4%B1k%C4%B0%C3%A7in%C4%B0yikiVars%C4%B1n%C4%B1z",
#     "promoted_content": null,
#     "query": "%23%C4%B0nsanl%C4%B1k%C4%B0%C3%A7in%C4%B0yikiVars%C4%B1n%C4%B1z",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u062e\u0631\u0648\u0641_\u0645\u0637\u0639\u0645_\u0627\u0644\u0645\u062c\u0645\u0631_\u0660\u0665\u0666\u0666\u0666\u0669\u0662\u0662\u0662\u0662",
#     "url": "http://twitter.com/search?q=%23%D8%AE%D8%B1%D9%88%D9%81_%D9%85%D8%B7%D8%B9%D9%85_%D8%A7%D9%84%D9%85%D8%AC%D9%85%D8%B1_%D9%A0%D9%A5%D9%A6%D9%A6%D9%A6%D9%A9%D9%A2%D9%A2%D9%A2%D9%A2",
#     "promoted_content": null,
#     "query": "%23%D8%AE%D8%B1%D9%88%D9%81_%D9%85%D8%B7%D8%B9%D9%85_%D8%A7%D9%84%D9%85%D8%AC%D9%85%D8%B1_%D9%A0%D9%A5%D9%A6%D9%A6%D9%A6%D9%A9%D9%A2%D9%A2%D9%A2%D9%A2",
#     "tweet_volume": null
#    },
#    {
#     "name": "#UygunFiyatlarrdannTTVerilir",
#     "url": "http://twitter.com/search?q=%23UygunFiyatlarrdannTTVerilir",
#     "promoted_content": null,
#     "query": "%23UygunFiyatlarrdannTTVerilir",
#     "tweet_volume": null
#    },
#    {
#     "name": "#StuffIDoInBed",
#     "url": "http://twitter.com/search?q=%23StuffIDoInBed",
#     "promoted_content": null,
#     "query": "%23StuffIDoInBed",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DPE2017",
#     "url": "http://twitter.com/search?q=%23DPE2017",
#     "promoted_content": null,
#     "query": "%23DPE2017",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Sevgili\u00d6zg\u00fcrl\u00fck",
#     "url": "http://twitter.com/search?q=%23Sevgili%C3%96zg%C3%BCrl%C3%BCk",
#     "promoted_content": null,
#     "query": "%23Sevgili%C3%96zg%C3%BCrl%C3%BCk",
#     "tweet_volume": null
#    },
#    {
#     "name": "#r4today",
#     "url": "http://twitter.com/search?q=%23r4today",
#     "promoted_content": null,
#     "query": "%23r4today",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0645\u0646\u0627\u0634\u062f\u0647_\u0627\u0644\u0645\u0628\u062a\u0639\u062b\u064a\u0646_\u0644\u0648\u0644\u064a_\u0627\u0644\u0639\u0647\u062f",
#     "url": "http://twitter.com/search?q=%23%D9%85%D9%86%D8%A7%D8%B4%D8%AF%D9%87_%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86_%D9%84%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF",
#     "promoted_content": null,
#     "query": "%23%D9%85%D9%86%D8%A7%D8%B4%D8%AF%D9%87_%D8%A7%D9%84%D9%85%D8%A8%D8%AA%D8%B9%D8%AB%D9%8A%D9%86_%D9%84%D9%88%D9%84%D9%8A_%D8%A7%D9%84%D8%B9%D9%87%D8%AF",
#     "tweet_volume": 24433
#    },
#    {
#     "name": "#Nirdosh",
#     "url": "http://twitter.com/search?q=%23Nirdosh",
#     "promoted_content": null,
#     "query": "%23Nirdosh",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LaCafeteraApocalipsisTrump",
#     "url": "http://twitter.com/search?q=%23LaCafeteraApocalipsisTrump",
#     "promoted_content": null,
#     "query": "%23LaCafeteraApocalipsisTrump",
#     "tweet_volume": null
#    },
#    {
#     "name": "#1921Trailer",
#     "url": "http://twitter.com/search?q=%231921Trailer",
#     "promoted_content": null,
#     "query": "%231921Trailer",
#     "tweet_volume": null
#    },
#    {
#     "name": "#VekilebehemsireyeKadro",
#     "url": "http://twitter.com/search?q=%23VekilebehemsireyeKadro",
#     "promoted_content": null,
#     "query": "%23VekilebehemsireyeKadro",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Montparnasse",
#     "url": "http://twitter.com/search?q=%23Montparnasse",
#     "promoted_content": null,
#     "query": "%23Montparnasse",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PranabMukherjee",
#     "url": "http://twitter.com/search?q=%23PranabMukherjee",
#     "promoted_content": null,
#     "query": "%23PranabMukherjee",
#     "tweet_volume": null
#    },
#    {
#     "name": "#noradkonf",
#     "url": "http://twitter.com/search?q=%23noradkonf",
#     "promoted_content": null,
#     "query": "%23noradkonf",
#     "tweet_volume": null
#    },
#    {
#     "name": "#\u0633\u062f\u0627\u062f_\u0642\u0631\u0648\u0636_\u06f0\u0665\u06f3\u06f3\u06f8\u06f1\u0665\u06f3\u06f1\u06f8",
#     "url": "http://twitter.com/search?q=%23%D8%B3%D8%AF%D8%A7%D8%AF_%D9%82%D8%B1%D9%88%D8%B6_%DB%B0%D9%A5%DB%B3%DB%B3%DB%B8%DB%B1%D9%A5%DB%B3%DB%B1%DB%B8",
#     "promoted_content": null,
#     "query": "%23%D8%B3%D8%AF%D8%A7%D8%AF_%D9%82%D8%B1%D9%88%D8%B6_%DB%B0%D9%A5%DB%B3%DB%B3%DB%B8%DB%B1%D9%A5%DB%B3%DB%B1%DB%B8",
#     "tweet_volume": null
#    },
#    {
#     "name": "#debatSER21D",
#     "url": "http://twitter.com/search?q=%23debatSER21D",
#     "promoted_content": null,
#     "query": "%23debatSER21D",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RejectedCountryBandNames",
#     "url": "http://twitter.com/search?q=%23RejectedCountryBandNames",
#     "promoted_content": null,
#     "query": "%23RejectedCountryBandNames",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ForoInternacionalDDHH",
#     "url": "http://twitter.com/search?q=%23ForoInternacionalDDHH",
#     "promoted_content": null,
#     "query": "%23ForoInternacionalDDHH",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SegundaDetremuraSDV",
#     "url": "http://twitter.com/search?q=%23SegundaDetremuraSDV",
#     "promoted_content": null,
#     "query": "%23SegundaDetremuraSDV",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AR11D",
#     "url": "http://twitter.com/search?q=%23AR11D",
#     "promoted_content": null,
#     "query": "%23AR11D",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TanyaKPK",
#     "url": "http://twitter.com/search?q=%23TanyaKPK",
#     "promoted_content": null,
#     "query": "%23TanyaKPK",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CalegPKB",
#     "url": "http://twitter.com/search?q=%23CalegPKB",
#     "promoted_content": null,
#     "query": "%23CalegPKB",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2017-12-11T09:31:51Z",
#   "created_at": "2017-12-11T09:29:47Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
#
# [
#  {
#   "trends": [
#    {
#     "name": "#MondayMotivation",
#     "url": "http://twitter.com/search?q=%23MondayMotivation",
#     "promoted_content": null,
#     "query": "%23MondayMotivation",
#     "tweet_volume": 25862
#    },
#    {
#     "name": "Start in die Woche",
#     "url": "http://twitter.com/search?q=%22Start+in+die+Woche%22",
#     "promoted_content": null,
#     "query": "%22Start+in+die+Woche%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Montagmorgen",
#     "url": "http://twitter.com/search?q=Montagmorgen",
#     "promoted_content": null,
#     "query": "Montagmorgen",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheWalkingDead",
#     "url": "http://twitter.com/search?q=%23TheWalkingDead",
#     "promoted_content": null,
#     "query": "%23TheWalkingDead",
#     "tweet_volume": 189415
#    },
#    {
#     "name": "#Montagslaecheln",
#     "url": "http://twitter.com/search?q=%23Montagslaecheln",
#     "promoted_content": null,
#     "query": "%23Montagslaecheln",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Krimi",
#     "url": "http://twitter.com/search?q=%23Krimi",
#     "promoted_content": null,
#     "query": "%23Krimi",
#     "tweet_volume": null
#    },
#    {
#     "name": "Waffen",
#     "url": "http://twitter.com/search?q=Waffen",
#     "promoted_content": null,
#     "query": "Waffen",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KOESCF",
#     "url": "http://twitter.com/search?q=%23KOESCF",
#     "promoted_content": null,
#     "query": "%23KOESCF",
#     "tweet_volume": null
#    },
#    {
#     "name": "Schnee",
#     "url": "http://twitter.com/search?q=Schnee",
#     "promoted_content": null,
#     "query": "Schnee",
#     "tweet_volume": 21957
#    },
#    {
#     "name": "K\u00f6ln",
#     "url": "http://twitter.com/search?q=K%C3%B6ln",
#     "promoted_content": null,
#     "query": "K%C3%B6ln",
#     "tweet_volume": 13699
#    },
#    {
#     "name": "Halbzeit",
#     "url": "http://twitter.com/search?q=Halbzeit",
#     "promoted_content": null,
#     "query": "Halbzeit",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Tatort",
#     "url": "http://twitter.com/search?q=%23Tatort",
#     "promoted_content": null,
#     "query": "%23Tatort",
#     "tweet_volume": null
#    },
#    {
#     "name": "#St\u00f6ger",
#     "url": "http://twitter.com/search?q=%23St%C3%B6ger",
#     "promoted_content": null,
#     "query": "%23St%C3%B6ger",
#     "tweet_volume": null
#    },
#    {
#     "name": "#schwiegertochtergesucht",
#     "url": "http://twitter.com/search?q=%23schwiegertochtergesucht",
#     "promoted_content": null,
#     "query": "%23schwiegertochtergesucht",
#     "tweet_volume": null
#    },
#    {
#     "name": "#bvbsvw",
#     "url": "http://twitter.com/search?q=%23bvbsvw",
#     "promoted_content": null,
#     "query": "%23bvbsvw",
#     "tweet_volume": null
#    },
#    {
#     "name": "#H96TSG",
#     "url": "http://twitter.com/search?q=%23H96TSG",
#     "promoted_content": null,
#     "query": "%23H96TSG",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TagderMenschenrechte",
#     "url": "http://twitter.com/search?q=%23TagderMenschenrechte",
#     "promoted_content": null,
#     "query": "%23TagderMenschenrechte",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AnneWill",
#     "url": "http://twitter.com/search?q=%23AnneWill",
#     "promoted_content": null,
#     "query": "%23AnneWill",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HumanRightsDay",
#     "url": "http://twitter.com/search?q=%23HumanRightsDay",
#     "promoted_content": null,
#     "query": "%23HumanRightsDay",
#     "tweet_volume": 176658
#    },
#    {
#     "name": "#ranNFL",
#     "url": "http://twitter.com/search?q=%23ranNFL",
#     "promoted_content": null,
#     "query": "%23ranNFL",
#     "tweet_volume": null
#    },
#    {
#     "name": "#fcspmsv",
#     "url": "http://twitter.com/search?q=%23fcspmsv",
#     "promoted_content": null,
#     "query": "%23fcspmsv",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SEAvsJAX",
#     "url": "http://twitter.com/search?q=%23SEAvsJAX",
#     "promoted_content": null,
#     "query": "%23SEAvsJAX",
#     "tweet_volume": 18362
#    },
#    {
#     "name": "#FCKFCI",
#     "url": "http://twitter.com/search?q=%23FCKFCI",
#     "promoted_content": null,
#     "query": "%23FCKFCI",
#     "tweet_volume": null
#    },
#    {
#     "name": "#KitchenImpossible",
#     "url": "http://twitter.com/search?q=%23KitchenImpossible",
#     "promoted_content": null,
#     "query": "%23KitchenImpossible",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HadeB",
#     "url": "http://twitter.com/search?q=%23HadeB",
#     "promoted_content": null,
#     "query": "%23HadeB",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CWLDallas",
#     "url": "http://twitter.com/search?q=%23CWLDallas",
#     "promoted_content": null,
#     "query": "%23CWLDallas",
#     "tweet_volume": 18184
#    },
#    {
#     "name": "#GERDEN",
#     "url": "http://twitter.com/search?q=%23GERDEN",
#     "promoted_content": null,
#     "query": "%23GERDEN",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BMGS04",
#     "url": "http://twitter.com/search?q=%23BMGS04",
#     "promoted_content": null,
#     "query": "%23BMGS04",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FCBayernXmas",
#     "url": "http://twitter.com/search?q=%23FCBayernXmas",
#     "promoted_content": null,
#     "query": "%23FCBayernXmas",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ManchesterDerby",
#     "url": "http://twitter.com/search?q=%23ManchesterDerby",
#     "promoted_content": null,
#     "query": "%23ManchesterDerby",
#     "tweet_volume": 79597
#    },
#    {
#     "name": "#ESLProLeague",
#     "url": "http://twitter.com/search?q=%23ESLProLeague",
#     "promoted_content": null,
#     "query": "%23ESLProLeague",
#     "tweet_volume": 18316
#    },
#    {
#     "name": "#GoPackGo",
#     "url": "http://twitter.com/search?q=%23GoPackGo",
#     "promoted_content": null,
#     "query": "%23GoPackGo",
#     "tweet_volume": 40401
#    },
#    {
#     "name": "#Browns",
#     "url": "http://twitter.com/search?q=%23Browns",
#     "promoted_content": null,
#     "query": "%23Browns",
#     "tweet_volume": 29577
#    },
#    {
#     "name": "#ReadyPlayerOne",
#     "url": "http://twitter.com/search?q=%23ReadyPlayerOne",
#     "promoted_content": null,
#     "query": "%23ReadyPlayerOne",
#     "tweet_volume": 24516
#    },
#    {
#     "name": "#Antisemitismus",
#     "url": "http://twitter.com/search?q=%23Antisemitismus",
#     "promoted_content": null,
#     "query": "%23Antisemitismus",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Petersen",
#     "url": "http://twitter.com/search?q=%23Petersen",
#     "promoted_content": null,
#     "query": "%23Petersen",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2017-12-11T09:31:51Z",
#   "created_at": "2017-12-11T09:24:50Z",
#   "locations": [
#    {
#     "name": "Germany",
#     "woeid": 23424829
#    }
#   ]
#  }
# ]

# %% [markdown]
# Interessant ist es jetzt, rauszufinden, wie üblich ein gewisser Trend in den einzelnen Regionen ist. Dazu benutzen wir Pythons `set` Datenstruktur, mit deren Hilfe wir zum einen herausfinden können, welche gemeinsamen Trends in den jeweiligen Regionen vorkommen, aber auch welche Trends nur in einer der Regionen vorkommen.

# %%
ww_trend_set = set([trend['name'] for trend in ww_trends[0]['trends']])

d_trend_set = set([trend['name'] for trend in d_trends[0]['trends']])

common_trends = ww_trend_set.intersection(d_trend_set)
difference_trends = ww_trend_set.symmetric_difference(d_trend_set)

print("Gemeinsame Trends: ", common_trends)
print()
print("Unterschiedliche Trending Topics: " ,difference_trends)
# Out:
# Gemeinsame Trends:  {'#Schlecker', 'Jimi Hendrix', '#MondayMotivation'}
#
# Unterschiedliche Trending Topics:  {'#Totensonntag', '#some17', '#Götze', '#قضيه_دخول_المجلس', '#JogoDePanelas', '#TGSHulingHuli', '#EuSouBoboMas', '#schwiegertochtergesucht', '#TheBestFeelingIn5Words', '#LLSPowerUp', '#CyberMonday', '#nurderHSV', 'Peing', '#VRC17', '#Blitzer', 'Ungleichheit', '#vouli', '#SoldChaiNotNation', '#BVBS04', '#qanda', 'Cyber Monday', '#FarkındamısınBilmiyorumAma', '#كيف_تدخر_من_راتبك', '#Watzke', '#Pakistan', '#Montagslaecheln', 'Selahattin Demirtaş', '#QuemSabeUmDiaEu', '#しゃべくり007', '#BoycottNetflix', 'Start in die Woche', '#Montella', '#Bonn', '#InfinityWar', '#LancashireDay', '#AnneWill', 'Ismail Yozgat', '#sps_live', '#Stöger', '#Sicherheit', '#jhv2017', '#好きな映画を雑に説明する', '#IwillVote4NawazSharif', '#SignsYoureMarriedToASpy', '#Higuain', '#AdoteUmaCriança', '#SegundaDetremuraSDV', '#SPPRAudioOnDec6', '#Hadiya', '#Neureuther', '#Breitscheidplatz', '#Fabio', '#나를_오프에서_본_후기', 'Prinz Harry', '#dmco17', '#AUEBOC', '#EmergenciaMachista', '#الغاء_برنامج_مجلس_الشباب', '#FelizLunes', '#LabanPilipinas', 'Meghan Markle', '#HambacherForst', '#OERde17', 'Kensington Palace', 'Phil Collins', '#كرتون_قطر', '#OTDirecto27N', '#LukesWoche', '#DiaDelMaestro', '#BMGFCB', '#ecommerce', 'Gilas', '#fwk17', '#Tatort', '#GroKo', '#تعرف_سيلفا', '#tt_thue', '#27Nov', 'South Africa', '#royalwedding', '#HadeB', 'Führerschein', '#Formel1', '#Oberhausen', '#IndustrialStrategy', '#HSVTSG', '#Cadem', '#PSU2017', '#AbuDhabiGP', '#زد_رصيدك56', '#Rohingya', 'Romelu Lukaku', '#Amri', '#Bali'}

# %% [markdown]
# ### Suchen nach Tweets
#
# Um Analysen mithilfe von Twitter zu betreiben, ist es selbsterklärend, dass wir nach Tweets zu einem bestimmten Thema suchen. Dies können politische, sportliche, so wie prominente Themen sein oder man findet seine Tweets unter einem Hashtag, welcher im Moment trendet.
#
#
# Zum Zeitpunkt, als ich an dieser Ausarbeitung gearbeitet habe, hat beispielsweise in den Vereingten Staaten der Hashtag *#TookMeTheWholeYearTo* getrendet. Deshalb nehm ich diesen als Beispiel für meinen nächsten Abschnitt.

# %%
q = '#TookMeTheWholeYearTo'

count = 100

# siehe https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

search_results = twitter_api.search.tweets(q=q, count=count)
statuses = search_results['statuses']

# Wir werden 5 Mal die Ergebnisse durchlaufen.

for _ in range(5):
    print ('Length of statuses', len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # Keine Ergebnisse mehr, wenn next_results nicht mehr existiert
         break
            
    # Erstelle ein dictionary von next_results, welches die folgende Form hat:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
        
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']
# Out:
# Length of statuses 13

# %%
# Anzeigen eines Such-Ergebnis-Beispiels
print(json.dumps(statuses[0], indent = 1))
# Out:
# {
#  "created_at": "Mon Nov 27 04:12:50 +0000 2017",
#  "id": 934998422704349184,
#  "id_str": "934998422704349184",
#  "text": "RT @PamJenk042071: #TookMeTheWholeYearTo decide I need another year to get my shit together",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "TookMeTheWholeYearTo",
#     "indices": [
#      19,
#      40
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "PamJenk042071",
#     "name": "Pam~demonium",
#     "id": 889433842276290560,
#     "id_str": "889433842276290560",
#     "indices": [
#      3,
#      17
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 796812288690950144,
#   "id_str": "796812288690950144",
#   "name": "CatfishMilkTheSadDrummerBoy",
#   "screen_name": "CatfishMilk",
#   "location": "blonded ",
#   "description": "I don't want some head I want your meds",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 372,
#   "friends_count": 151,
#   "listed_count": 2,
#   "created_at": "Thu Nov 10 20:30:28 +0000 2016",
#   "favourites_count": 25825,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 7503,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/934555394965458945/4NS7pjqA_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/934555394965458945/4NS7pjqA_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/796812288690950144/1511267910",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Sat Nov 25 08:01:39 +0000 2017",
#   "id": 934331230950215680,
#   "id_str": "934331230950215680",
#   "text": "#TookMeTheWholeYearTo decide I need another year to get my shit together",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "TookMeTheWholeYearTo",
#      "indices": [
#       0,
#       21
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 889433842276290560,
#    "id_str": "889433842276290560",
#    "name": "Pam~demonium",
#    "screen_name": "PamJenk042071",
#    "location": "Hagerstown, MD",
#    "description": "Gifted in  sarcasm, mom of three, nursing student, with a touch of my sanity left",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 253,
#    "friends_count": 377,
#    "listed_count": 0,
#    "created_at": "Mon Jul 24 10:35:27 +0000 2017",
#    "favourites_count": 3673,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 1785,
#    "lang": "en",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/934942877813235712/dzp-wr4l_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/934942877813235712/dzp-wr4l_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/889433842276290560/1511337611",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 5,
#   "favorite_count": 17,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 5,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "en"
# }

# %% [markdown]
# Wie man sehen kann, sind Tweets gespickt von großen Mengen Metadaten: Bei jedem Tweet wird gespeichert, wann er erstellt wurde, von wem er erstellt wurde, welche Hashtags verwendet wurden, die einzelnen user_mentions, von welcher Twitter App der Tweet gesendet wurde (hier: Twitter for Android), ob der Tweet eine Antwort war auf einen anderen Tweet.
#
# Außerdem werden durch den Tweet Metadaten im Bezug auf den User gespeichert: Zum einen haben wir hier die id, den Username, die angegebene Location, eine selbst angegebene Beschreibung des Users, ob der Account des Users privat ist oder nicht, wie viele Follower der User hat und wie vielen anderen Twitter-Usern er folgt, wie viele Favoriten der User hat, wann der Twitter-Account erstellt wurde, wie viele Tweets der Account bisher hat und so weiter.
#
# Es ist erstaunlich wie viel aus einem 280-Zeichen Text herausgelesen werden kann. Mithilfe der Medadaten könnte man auch sehr viele unterschiedliche Analysen aufstellen.
#
#
# ## Analyse der 280 Zeichen
#
# Wir extrahieren einen einzelnen tweet von unserem Suchergebnis in einer Variable `t`. Nun können wir verschiedene Aspekte des Tweets anzeigen lassen.

# %%
t = statuses[0]
print(t['text']) # zeigt den Tweet an
print()
print(t['id']) # gibt uns die id des User von unserem Tweet aus
print()
print(t['entities']) # gibt uns die Entitäten eines Tweets zurück
print()
print(t['favorite_count']) #Zeigt uns die Anzahl der Favoriten an, die unser Tweet erhalten hat. In unserem Beispiel ist das 0

# siehe https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object
# Out:
# RT @PamJenk042071: #TookMeTheWholeYearTo decide I need another year to get my shit together
#
# 934998422704349184
#
# {'hashtags': [{'text': 'TookMeTheWholeYearTo', 'indices': [19, 40]}], 'symbols': [], 'user_mentions': [{'screen_name': 'PamJenk042071', 'name': 'Pam~demonium', 'id': 889433842276290560, 'id_str': '889433842276290560', 'indices': [3, 17]}], 'urls': []}
#
# 0

# %% [markdown]
# ### Extrahieren von Tweet-Entititäten
#
# Als nächstes werden wir die Entitäten eines Tweets in einer passenden Datenstruktur darstellen, um uns die nachfolgende Analyse zu erleichtern.

# %%
status_texts = [ status['text'] for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                for status in statuses
                    for user_mention in status['entities']['user_mentions']]

hashtags = [ hashtag['text']
               for status in statuses
                   for hashtag in status['entities']['hashtags']]

# Errechne eine Sammlung aller Wörter von allen Tweets

words = [ w
            for t in status_texts
                for w in t.split() ]

# %%
#Ausgabe

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1))
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @PamJenk042071: #TookMeTheWholeYearTo decide I need another year to get my shit together",
#  "RT @radikalchikken: #TookMeTheWholeYearTo grow back my eyebrows after a horrible incident involving flatulence and a scented candle.",
#  "RT @ETAMDEGGUR: #TookMeTheWholeYearTo\nTo capture this ginger boy. https://t.co/ho4WDtRDLB",
#  "RT @ellelljaytoo: #TookMeTheWholeYearTo get from the bottom! Now we here, wooot! #HalfwayThere See y'all next year!\ud83d\ude43\n\n#StriveForGreatness\u2026",
#  "RT @tvserieshub: #TookMeTheWholeYearTo be in November now."
# ]
# [
#  "PamJenk042071",
#  "radikalchikken",
#  "ETAMDEGGUR",
#  "ellelljaytoo",
#  "tvserieshub"
# ]
# [
#  "TookMeTheWholeYearTo",
#  "TookMeTheWholeYearTo",
#  "TookMeTheWholeYearTo",
#  "TookMeTheWholeYearTo",
#  "HalfwayThere"
# ]
# [
#  "RT",
#  "@PamJenk042071:",
#  "#TookMeTheWholeYearTo",
#  "decide",
#  "I"
# ]

# %% [markdown]
# Wir haben uns hier 5 Tweets, 5 Usernamen und 5 Hashtags (natürlich dominiert hier `#TookMeTheWholeYearTo`, da wir ursprünglich danach gesucht hatten) ausgeben lassen.
#
#
# ### Analyse von Tweets und Tweetentitäten mit Häufigkeitsanalyse
#
# Bei einer Analyse interessiert uns natürlich, immer wie häufig ein gewisses Ereignis ist.
#
# Gerade eben haben wir uns einfach die ersten 5 Ergebnisse unserer Suche ausgeben lassen, ohne auf eine gewisse Rangliste zu achten.
#
# Nun werden wir die Daten unserer Suche genauer betrachten, indem wir die Häufigkeitsverteilung berechnen, mit Hinblick auf die Top-10 Elemente unserer Suche.
#
# Dazu steht uns das `collections` Modul von Python zur Verfügung. Es liefert uns einen `Counter` der das berechnen einer Häufigkeitsverteilung erleichtert. Im folgenden Beispiel werden wir sehen, wie wir dies mit unseren Tweets verbinden können.

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print (c.most_common()[:10]) # Top-10
    print()
# Out:
# [('#TookMeTheWholeYearTo', 63), ('RT', 48), ('the', 24), ('my', 17), ('to', 14), ('that', 14), ('I', 12), ('a', 12), ('you', 12), ('@ETAMDEGGUR:', 9)]
#
# [('ETAMDEGGUR', 9), ('keet0007', 4), ('EricWolfson', 3), ('ellelljaytoo', 2), ('renatoseixas75', 2), ('1KennyBania', 2), ('RealTrumpClone', 2), ('animalpenpals', 2), ('PamJenk042071', 1), ('radikalchikken', 1)]
#
# [('TookMeTheWholeYearTo', 63), ('tookmethewholeyearto', 3), ('HalfwayThere', 2), ('StriveForGreatness', 2), ('THICK', 2), ('Jesus', 2), ('God', 2), ('Perfection', 1), ('TookMeTheWholeYearToِ', 1), ('HolySpirit', 1)]

# %% [markdown]
# Das Ergbnis der Häufigkeitsverteilung ist eine Karte von Schlüssel- beziehungsweise Werte-Paaren mit den dazugehörigen Häufigkeiten.
#
# Um das ganze leichter zu analysieren, werden wir das Ergebnis als Tabelle anzeigen lassen.
# Dazu installieren wir das Package `prettytable` auf die selbe Weise wie wir schon `Twitter` zu Beginn in Python installiert haben (**`pip install prettytable`**).

# %%
from prettytable import PrettyTable

for label, data in (('Word', words),
                    ('Screen Name', screen_names),
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count'])
    
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Spaltenausrichtung festlegen
    print(pt)
# Out:
# +-----------------------+-------+
# | Word                  | Count |
# +-----------------------+-------+
# | #TookMeTheWholeYearTo |    63 |
# | RT                    |    48 |
# | the                   |    24 |
# | my                    |    17 |
# | to                    |    14 |
# | that                  |    14 |
# | I                     |    12 |
# | a                     |    12 |
# | you                   |    12 |
# | @ETAMDEGGUR:          |     9 |
# +-----------------------+-------+
# +----------------+-------+
# | Screen Name    | Count |
# +----------------+-------+
# | ETAMDEGGUR     |     9 |
# | keet0007       |     4 |
# | EricWolfson    |     3 |
# | ellelljaytoo   |     2 |
# | renatoseixas75 |     2 |
# | 1KennyBania    |     2 |
# | RealTrumpClone |     2 |
# | animalpenpals  |     2 |
# | PamJenk042071  |     1 |
# | radikalchikken |     1 |
# +----------------+-------+
# +----------------------+-------+
# | Hashtag              | Count |
# +----------------------+-------+
# | TookMeTheWholeYearTo |    63 |
# | tookmethewholeyearto |     3 |
# | HalfwayThere         |     2 |
# | StriveForGreatness   |     2 |
# | THICK                |     2 |
# | Jesus                |     2 |
# | God                  |     2 |
# | Perfection           |     1 |
# | TookMeTheWholeYearToِ |     1 |
# | HolySpirit           |     1 |
# +----------------------+-------+

# %% [markdown]
# Nun könnten sich beispielsweise irgendwelche Zusammenhänge herauskristallisieren, was man bei Hashtags, die ein gewisses Event betreffen (zum Beispiel *#WorldCup2018*), sehen würde. In unserem Beispiel hier kann man leider keine wirklichen Zusammenhänge erkennen. Dies liegt wahrscheinlich daran, dass unter unserem Hashtag nur persönliche Dinge getweetet werden und diese sich von User zu User zu stark unterscheiden.
#
# Was man jedoch schön sehen kann bei der Kategorie Hashtag, ist, dass unser Hashtag in all seinen Variationen der Groß- und Kleinschreibung vorkommt. Es wäre also lohnenswert wenn man jedes Wort auf Kleinbuchstaben normalisiert, um ein unverfälschteres Ergebnis zu bekommen.

# %% [markdown]
# # <span style="color:red">Kommentar JI</span>
#  Es wäre schön, wenn du auch das zeigen würdest um die Unterschiede zu sehen.

# %% [markdown]
# ### Lexikalische Vielfalt von Tweets
#
# Eine etwas fortgeschrittenere Messung, welche das Berechnen von einfachen Häufigkeiten beinhaltet und auch an unstrukturierten Texten angewendet werden kann, ist eine Methode, die als **Lexikalische Vielfalt** bezeichnet wird.
#
# Mathematisch gesehen ist dies ein Ausdruck für die Zahl der *einzigartigen* Token in einem Text geteilt durch die Gesamtanzahl aller Token im Text. Lexikalische Vielfalt drückt vorallem die Vielfältigkeit des Vokabulars eines Individuums oder einer Gruppe aus. Wenn eine Person viele sich voneinander unterscheidende Wörter verwendet, um etwas zu erklären, drückt das eine höhere lexikalische Vielfalt aus, als jemand der nur einfache Wörter und davon immer dieselben benutzt. Daraufhin kann man auch zum Teil auf die Intelligenz einer Person schließen, da davon ausgegangen werden kann, dass gebildete Personen über einen breiteren Wortschatz verfügen, als Personen, die eine weniger hohe Bildung erfahren haben.
#
# Auch bei Tweets kann die Lexikalische Vielfalt Aufschluss geben über die Breite, beziehungsweise Enge, eines bestimmten Themas, welches im Moment diskutiert wird. Augrund der minimalen Zeichenbegrenzung ist dies zwar nicht so ausschlaggebend wie beispielsweise in einer 10 Seiten langen Rede, ist jedoch trotzdem einer Überlegung wert.
#
# Um dies an einem Beispiel zu verdeutlichen, werden wir diese Methode auf unseren Datensatz anwenden.

# %%
def lexical_diversity(tokens): #Funktion zum Berechnen der Lexikalischen Vielfalt
    return 1.0*len(set(tokens))/len(tokens)

def average_words(statuses): #Funktion um die durchschnittliche Anzahl der Wörter eines Tweets zu berechnen
    total_words = sum([ len(s.split()) for s in statuses ])
    return 1.0*total_words/len(statuses)

# %%
#Ausgabe

print('Lexikalische Vielfalt der Wörter: ', lexical_diversity(words))
print('Lexikalische Vielfalt der Usernamen: ', lexical_diversity(screen_names))
print('Lexikalische Vielfalt der Hashtags: ', lexical_diversity(hashtags))
print('Durchschnitt. # der Wörter eines Tweets: ', average_words(status_texts))
# Out:
# Lexikalische Vielfalt der Wörter:  0.46375
# Lexikalische Vielfalt der Usernamen:  0.625
# Lexikalische Vielfalt der Hashtags:  0.12658227848101267
# Durchschnitt. # der Wörter eines Tweets:  11.940298507462687

# %% [markdown]
# Folgende Beobachtungen können wir aus dem Ergebnis ablesen:
#
# - Die lexikalische Vielfalt der Wörter unseres Datensatzes ist nicht sehr hoch: Jeder Tweet fasst nur etwa 46% eindeutige Wörter. Die durchschnittliche Anzahl der Wörter in den einzelnen Tweets beträgt hier etwa 11, das bedeutet, dass in jedem Tweet etwa 5 einzigartige Wörter vorkommen.
# - Die lexikalische Vielfalt der Usernamen unseres Datensatzes ist höher, sie beträgt etwa 62%. Das bedeutet, dass etwa 12 von 20 Usernamen in unserem Datensatz einzigartig sind, also nur ein einziges mal beim Erstellen unseres Datensatz mit unserem Hashtag getweeted haben. Also etwa die Hälfte der User hat nur einmal getweeted.
# - Die lexikalische Vielfalt der Hashtags unseres Datensatzes ist sehr gering, sie beträgt nur 12%. Das bedeutet, dass nur  sehr wenige einzigartigen Hashtags neben unserem gesuchten Hashtags verwendet wurden. Dies macht Sinn, da die Tweets sogesehen eine Reaktion auf unseren Hashtags darstellen. Dies erklärt auch die geringe Anzahl an Wörtern in unseren Tweets.
#
#
#
# ### Analyse von Retweets
#
# Eine Besonderheit bei Twitter sind Retweets. Zu den Anfangzeiten von Twitter gab es keine von Twitter implementierte Retweet-API. Dies hatte zur Folge, dass die User damals Tweets geteilt haben, indem sie den Tweet in einen eigenen Tweet kopiert hatten und ihn mit RT @ursprünglicherVerfasser gekennzeichnet haben. Heute ist dies nicht mehr üblich, da Twitter eine eigene Retweet-Funktion integriert hat.
#
# Wir wollen nun wissen, welche Tweets unseres Datensatzes am häufigsten geteilt wurden. Dafür gehen wir durch jeden Tweet durch, speichern die Anzahl der Retweets, den Autor des Tweets und den Text des Tweets ab.

# %%
retweets = [
            # Speichern eines Tupels dieser 3 Werte...
            (status['retweet_count'],
             status['retweeted_status']['user']['screen_name'],
             status['text'])
            
            #... für jeden Status...
            for status in statuses
    
            #... sofern der Status diese Bedingung erfüllt
                if 'retweeted_status' in status
            ]

# %%
#Ausgabe der ersten 5 des sortierten Ergebnisses
pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
#Darstellung jedes Elements im Tupel
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ] 
pt.max_width['Text'] = 50
pt.align = 'l'
print(pt)
# Out:
# +-------+---------------+----------------------------------------------------+
# | Count | Screen Name   | Text                                               |
# +-------+---------------+----------------------------------------------------+
# | 29    | ErinLea7      | RT @ErinLea7: It #TookMeTheWholeYearTo finally     |
# |       |               | choose me. https://t.co/nEzjhhb6CP                 |
# | 26    | CoolChris_007 | RT @CoolChris_007: #TookMeTheWholeYearTo come up   |
# |       |               | with a better password https://t.co/PREc0283cH     |
# | 21    | IamDHop       | RT @IamDHop: #TookMeTheWholeYearTo put an "X" on   |
# |       |               | everyday of the calendar. https://t.co/eDQBsaWw24  |
# | 19    | SassyFacts_1  | RT @SassyFacts_1: #TookMeTheWholeYearTo realize    |
# |       |               | those pesky kids I kept yelling at to get off my   |
# |       |               | lawn were actually garden gnomes                   |
# | 15    | derrold       | RT @derrold: #TookMeTheWholeYearTo Get one good    |
# |       |               | night's sleep. https://t.co/lKOTPCibxd             |
# +-------+---------------+----------------------------------------------------+

# %% [markdown]
# An unserem Ergebnis kann man sehen, dass der Tweet mit den meisten Retweets 29 mal geteilt wurde. Hier können wir auch sehen, dass die interne Retweet-Funktion von Twitter genutzt wird, da sich kein einziger Screen Name mit dem des Tweets unterscheidet, wie es früher noch der Fall gewesen wäre.

# %% [markdown]
# ### Graphische Analysen
#
# Zu einer guten Analyse gehört selbstverständlich auch eine graphische Darstellung der ausgewerteten Daten. Dazu gehören Plots, Histogramme oder andere Darstellungsweisen. Wir werden hier einmal einen Plot und dann ein Histogramm sehen. Natürlich gibt es mehrere Varianten mit denen man sich beschäftigen kann.
#
# Als Erstes werden wir eine Analyse mithilfe eines Plots machen. Dazu benutzen wir das package `mathplotlib`. Für unseren Plot ziehen wir die Daten her, die wir in einem Beispiel weiter oben gesammelt haben - und zwar die Häufigkeiten einzelner Wörter (*siehe Analyse von Tweets und Tweetentitäten mit Häufigkeitsanalyse*). Die Y-Achse zeigt uns, wie oft ein Wort verwendet wurde, während die X-Achse angibt, um welches Wort es sich handelt. Dies korrespondiert mit unserer Tabelle, die wir im oben genannten Beispiel erstellt haben.

# %%
import matplotlib.pyplot as plt

word_counts = sorted(Counter(words).values(), reverse=True) # wir sortieren, so dass die Beziehung zu den Häufigkeiten besser hervorstechen

plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")
plt.show()

# %% [markdown]
# $10^0$ steht bei unserem Beispiel natürlich für unseren Hashtag *TookMeTheWholeYearTo*. Die Reihenfolge der nächsten Wörter kann man aus unserer *words* Tabelle ablesen. Dieser Plot war nur ein kleines Beispiel, was man machen könnte.
#
# Als nächstes wollen wir noch ein Histogramm erstellen. Histogramme werden in der Statistik gerne verwendet um Dinge zu veranschaulichen. Wir werden unsere Retweethäufigkeiten in Form eines Histogramms darstellen. Dazu gruppieren wir Datenwerte zu *bins* zusammen, die einem Bereich von Häufigkeiten entsprechen. In unserem Datensatz gibt es eine kleine ausgewählte Anzahl von Retweets, die mehr Retweets haben als jene, die beispielsweise nur einmal geteilt wurden. Folgendes Histogramm kommt dabei zu Stande:

# %%
counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel("Bins (Anzahl von Retweets)")
plt.ylabel("Anzahl von Tweets in einem bin")
plt.show()

# %% [markdown]
# Dieses Ergebnis war vorhersehbar, da es in unserem Datensatz nur sehr wenige Tweets gibt, die eine hohe Anzahl von Retweets vorweisen können - mit der höchsten Anzahl von 29 Retweets (Zum Vergleich: einer der Tweets mit den meisten Retweets stammt von Barack Obama mit über 1 Millionen Retweets). Im Gegensatz gibt es einige Tweets in unserem Datensatz, die nur einen Retweet erhalten haben, was wir an dem ersten großen Balken in unserem Histogramm sehen können.
#
#
#
# ## Speichern der Daten
#
# Twitter ist ein sich schnell verändertes Medium. Die Daten werden nach Echtzeit bezogen, das bedeutet, Daten, die wir vor ein paar Stunden bezogen haben, können nachher schon nicht mehr da sein. Dies ist vorallem bei unserer Auswertung ein Problem. Bei jedem Neustart des Kernels durchlaufen wir das Suchen der Daten erneut, was für uns bedeutet, dass unsere Daten, welche wir bis dato gesammelt haben ersetzt werden durch neuere Daten. Um dies zu umgehen müssen wir unsere Daten in einem geeigneten Dateiformat speichern, um sie bei jedem Restart von dieser Datei aus wieder zu laden. Dazu eignet sich das .txt-Dateiformat, da es von vielen anderen Programmen gelesen und verwendet werden kann.
#
# Um das Speichern unserer Daten zu erleichtern, verwenden wir das io Python-Modul.

# %%
import  io,json



def save_json(filename,data): 
    json.dump(data, fp=open('resources/{0}.json'.format(filename), 'w'), indent=1) # Pfad, wo txt-Datei gespeicher werden soll; w = schreibrechte sind gegeben

# %% [markdown]
# Hierfür erstellen wir eine
#
# ```python
# def save_json(filename,data)
# ```
#
# Funktion, die unsere Tweets in einer Json Datei speichert. Der Funktion wird der Dateiname und die zu speichernden Tweets übergeben.
#
# Natürlich brauchen wir dann auch eine Funktion, durch die wir unsere Daten aus der Datei in Python laden können. Dies wird bei uns die
#
# ```python
# def load_json(filename)
# ```
#
# Funktion sein, der wir nur den Dateinamen übergeben müssen.

# %%
def load_json(filename):
    with io.open('resources/{0}.json'.format(filename),'r', encoding='utf-8') as f: # hier muss r stehen, damit die txt-Datei gelesen werden kann
        readfile = f.read()
        jsonfile = json.loads(readfile)
        return jsonfile

# %% [markdown]
# Als Beispiel nehmen wir mal den Hashtag *#TheWalkingDead*. Da zurzeit die neue Staffel in den USA läuft, können wir viele Tweets unter diesem Hashtag sammeln.

# %%
test = '#TheWalkingDead'

# %% [markdown]
# Nun holen wir mithilfe unserer API die tweets und speichern, sie in eine Datei mit dem Hashtag als unseren Dateinamen.

# %%
ergebnis = twitter_api.search.tweets(q=test, max_results=100)
ergstatus = ergebnis['statuses']


save_json(test, ergstatus)

# %% [markdown]
# Jetzt laden wir die Datei in Python und können sehen, dass nunmehr immer die gleichen Daten geladen werden, wir somit also das Problem des Kernelneustarts umgehen können.

# %%
twdtweets = load_json(test)
twdtweets
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Dec 16 18:41:37 +0000 2017',
#   'entities': {'hashtags': [{'indices': [42, 57], 'text': 'TheWalkingDead'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/Talk808',
#      'expanded_url': 'http://bit.ly/Talk808',
#      'indices': [106, 129],
#      'url': 'https://t.co/rH5Es6uE2X'}],
#    'user_mentions': [{'id': 14724725,
#      'id_str': '14724725',
#      'indices': [3, 18],
#      'name': 'The Walking Dead',
#      'screen_name': 'TheWalkingDead'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 942102432464678914,
#   'id_str': '942102432464678914',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 96,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat Dec 16 14:00:03 +0000 2017',
#    'entities': {'hashtags': [{'indices': [22, 37], 'text': 'TheWalkingDead'}],
#     'media': [{'display_url': 'pic.twitter.com/es0TLixJAd',
#       'expanded_url': 'https://twitter.com/TheWalkingDead/status/942031572684783616/photo/1',
#       'id': 941811226836795394,
#       'id_str': '941811226836795394',
#       'indices': [110, 133],
#       'media_url': 'http://pbs.twimg.com/media/DRH8UiUVAAIEHN1.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DRH8UiUVAAIEHN1.jpg',
#       'sizes': {'large': {'h': 666, 'resize': 'fit', 'w': 1000},
#        'medium': {'h': 666, 'resize': 'fit', 'w': 1000},
#        'small': {'h': 453, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/es0TLixJAd'}],
#     'symbols': [],
#     'urls': [{'display_url': 'bit.ly/Talk808',
#       'expanded_url': 'http://bit.ly/Talk808',
#       'indices': [86, 109],
#       'url': 'https://t.co/rH5Es6uE2X'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/es0TLixJAd',
#       'expanded_url': 'https://twitter.com/TheWalkingDead/status/942031572684783616/photo/1',
#       'id': 941811226836795394,
#       'id_str': '941811226836795394',
#       'indices': [110, 133],
#       'media_url': 'http://pbs.twimg.com/media/DRH8UiUVAAIEHN1.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DRH8UiUVAAIEHN1.jpg',
#       'sizes': {'large': {'h': 666, 'resize': 'fit', 'w': 1000},
#        'medium': {'h': 666, 'resize': 'fit', 'w': 1000},
#        'small': {'h': 453, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/es0TLixJAd'}]},
#    'favorite_count': 963,
#    'favorited': False,
#    'geo': None,
#    'id': 942031572684783616,
#    'id_str': '942031572684783616',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 96,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'How do you feel about #TheWalkingDead Mid-Season Finale after almost a week? Tell us: https://t.co/rH5Es6uE2X https://t.co/es0TLixJAd',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat May 10 14:14:51 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'The Official Walking Dead account from Skybound Entertainment. Make sure to also check out https://t.co/xFPK8aeZgx & https://t.co/Sw1AukmCnN. #TWDFamily',
#     'entities': {'description': {'urls': [{'display_url': 'bit.ly/TWDFacebook',
#         'expanded_url': 'http://bit.ly/TWDFacebook',
#         'indices': [91, 114],
#         'url': 'https://t.co/xFPK8aeZgx'},
#        {'display_url': 'bit.ly/TWDinsta',
#         'expanded_url': 'http://bit.ly/TWDinsta',
#         'indices': [117, 140],
#         'url': 'https://t.co/Sw1AukmCnN'}]},
#      'url': {'urls': [{'display_url': 'thewalkingdead.com',
#         'expanded_url': 'http://www.thewalkingdead.com',
#         'indices': [0, 22],
#         'url': 'http://t.co/cMPtTbZ0HZ'}]}},
#     'favourites_count': 8658,
#     'follow_request_sent': False,
#     'followers_count': 1640929,
#     'following': False,
#     'friends_count': 5233,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 14724725,
#     'id_str': '14724725',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 3032,
#     'location': 'Los Angeles, CA',
#     'name': 'The Walking Dead',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/795320524/70800432c4462230ac42af713ef5e92c.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/795320524/70800432c4462230ac42af713ef5e92c.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14724725/1444269144',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/875390678200573952/l0q5k995_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875390678200573952/l0q5k995_normal.jpg',
#     'profile_link_color': 'D00000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'TheWalkingDead',
#     'statuses_count': 20448,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'regular',
#     'url': 'http://t.co/cMPtTbZ0HZ',
#     'utc_offset': -28800,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @TheWalkingDead: How do you feel about #TheWalkingDead Mid-Season Finale after almost a week? Tell us: https://t.co/rH5Es6uE2X https://t…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jul 09 10:45:43 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Student with big dreams, and a stubborn attitude that will, eventually, get me there.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 2911,
#    'follow_request_sent': False,
#    'followers_count': 22,
#    'following': False,
#    'friends_count': 99,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 751729034413871104,
#    'id_str': '751729034413871104',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'United Kingdom',
#    'name': 'Jennifer Draper',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/751729034413871104/1486331831',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/828361770758717440/I0Fwn7z1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/828361770758717440/I0Fwn7z1_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JDraper1997',
#    'statuses_count': 795,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Dec 16 18:41:37 +0000 2017',
#   'entities': {'hashtags': [{'indices': [44, 59], 'text': 'thewalkingdead'},
#     {'indices': [60, 71], 'text': 'carlgrimes'}],
#    'media': [{'display_url': 'pic.twitter.com/gEIy77yuxt',
#      'expanded_url': 'https://twitter.com/andysnormxn/status/940720262877777920/video/1',
#      'id': 940720065414037510,
#      'id_str': '940720065414037510',
#      'indices': [72, 95],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/940720065414037510/pu/img/TyVvEWw9yvmstclI.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/940720065414037510/pu/img/TyVvEWw9yvmstclI.jpg',
#      'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 720, 'resize': 'fit', 'w': 720},
#       'small': {'h': 680, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 940720262877777920,
#      'source_status_id_str': '940720262877777920',
#      'source_user_id': 3044215257,
#      'source_user_id_str': '3044215257',
#      'type': 'photo',
#      'url': 'https://t.co/gEIy77yuxt'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 3044215257,
#      'id_str': '3044215257',
#      'indices': [3, 15],
#      'name': 'leah',
#      'screen_name': 'andysnormxn'}]},
#   'extended_entities': {'media': [{'additional_media_info': {'monetizable': False,
#       'source_user': {'contributors_enabled': False,
#        'created_at': 'Wed Feb 18 02:46:47 +0000 2015',
#        'default_profile': True,
#        'default_profile_image': False,
#        'description': '🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f',
#        'entities': {'description': {'urls': []},
#         'url': {'urls': [{'display_url': 'youtu.be/3xtb0r6d1fU',
#            'expanded_url': 'https://youtu.be/3xtb0r6d1fU',
#            'indices': [0, 23],
#            'url': 'https://t.co/CLkGcECqcu'}]}},
#        'favourites_count': 4731,
#        'follow_request_sent': False,
#        'followers_count': 893,
#        'following': False,
#        'friends_count': 2177,
#        'geo_enabled': True,
#        'has_extended_profile': True,
#        'id': 3044215257,
#        'id_str': '3044215257',
#        'is_translation_enabled': False,
#        'is_translator': False,
#        'lang': 'en',
#        'listed_count': 9,
#        'location': "🌹's",
#        'name': 'leah',
#        'notifications': False,
#        'profile_background_color': 'C0DEED',
#        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_tile': False,
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3044215257/1513122896',
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/940731719149375488/TQppL6_n_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/940731719149375488/TQppL6_n_normal.jpg',
#        'profile_link_color': '1DA1F2',
#        'profile_sidebar_border_color': 'C0DEED',
#        'profile_sidebar_fill_color': 'DDEEF6',
#        'profile_text_color': '333333',
#        'profile_use_background_image': True,
#        'protected': False,
#        'screen_name': 'andysnormxn',
#        'statuses_count': 3817,
#        'time_zone': 'Pacific Time (US & Canada)',
#        'translator_type': 'none',
#        'url': 'https://t.co/CLkGcECqcu',
#        'utc_offset': -28800,
#        'verified': False}},
#      'display_url': 'pic.twitter.com/gEIy77yuxt',
#      'expanded_url': 'https://twitter.com/andysnormxn/status/940720262877777920/video/1',
#      'id': 940720065414037510,
#      'id_str': '940720065414037510',
#      'indices': [72, 95],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/940720065414037510/pu/img/TyVvEWw9yvmstclI.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/940720065414037510/pu/img/TyVvEWw9yvmstclI.jpg',
#      'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 720, 'resize': 'fit', 'w': 720},
#       'small': {'h': 680, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 940720262877777920,
#      'source_status_id_str': '940720262877777920',
#      'source_user_id': 3044215257,
#      'source_user_id_str': '3044215257',
#      'type': 'video',
#      'url': 'https://t.co/gEIy77yuxt',
#      'video_info': {'aspect_ratio': [1, 1],
#       'duration_millis': 26693,
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/940720065414037510/pu/pl/RiuNnS6cgYHcMspk.m3u8'},
#        {'bitrate': 1280000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/940720065414037510/pu/vid/720x720/C5gPcSCYUCtrOSTu.mp4'},
#        {'bitrate': 320000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/940720065414037510/pu/vid/240x240/33rH1rdhaWvkTXTs.mp4'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/940720065414037510/pu/vid/480x480/bZRMbzchhjraTetR.mp4'}]}}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 942102431000821761,
#   'id_str': '942102431000821761',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 68,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Tue Dec 12 23:09:23 +0000 2017',
#    'entities': {'hashtags': [{'indices': [27, 42], 'text': 'thewalkingdead'},
#      {'indices': [43, 54], 'text': 'carlgrimes'}],
#     'media': [{'display_url': 'pic.twitter.com/gEIy77yuxt',
#       'expanded_url': 'https://twitter.com/andysnormxn/status/940720262877777920/video/1',
#       'id': 940720065414037510,
#       'id_str': '940720065414037510',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/940720065414037510/pu/img/TyVvEWw9yvmstclI.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/940720065414037510/pu/img/TyVvEWw9yvmstclI.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 720},
#        'medium': {'h': 720, 'resize': 'fit', 'w': 720},
#        'small': {'h': 680, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/gEIy77yuxt'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#       'display_url': 'pic.twitter.com/gEIy77yuxt',
#       'expanded_url': 'https://twitter.com/andysnormxn/status/940720262877777920/video/1',
#       'id': 940720065414037510,
#       'id_str': '940720065414037510',
#       'indices': [55, 78],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/940720065414037510/pu/img/TyVvEWw9yvmstclI.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/940720065414037510/pu/img/TyVvEWw9yvmstclI.jpg',
#       'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 720},
#        'medium': {'h': 720, 'resize': 'fit', 'w': 720},
#        'small': {'h': 680, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'video',
#       'url': 'https://t.co/gEIy77yuxt',
#       'video_info': {'aspect_ratio': [1, 1],
#        'duration_millis': 26693,
#        'variants': [{'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/940720065414037510/pu/pl/RiuNnS6cgYHcMspk.m3u8'},
#         {'bitrate': 1280000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/940720065414037510/pu/vid/720x720/C5gPcSCYUCtrOSTu.mp4'},
#         {'bitrate': 320000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/940720065414037510/pu/vid/240x240/33rH1rdhaWvkTXTs.mp4'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/940720065414037510/pu/vid/480x480/bZRMbzchhjraTetR.mp4'}]}}]},
#    'favorite_count': 145,
#    'favorited': False,
#    'geo': None,
#    'id': 940720262877777920,
#    'id_str': '940720262877777920',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 68,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'So I kinda wanna eat glass #thewalkingdead #carlgrimes https://t.co/gEIy77yuxt',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Feb 18 02:46:47 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '🏴\U000e0067\U000e0062\U000e0073\U000e0063\U000e0074\U000e007f',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'youtu.be/3xtb0r6d1fU',
#         'expanded_url': 'https://youtu.be/3xtb0r6d1fU',
#         'indices': [0, 23],
#         'url': 'https://t.co/CLkGcECqcu'}]}},
#     'favourites_count': 4731,
#     'follow_request_sent': False,
#     'followers_count': 893,
#     'following': False,
#     'friends_count': 2177,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 3044215257,
#     'id_str': '3044215257',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 9,
#     'location': "🌹's",
#     'name': 'leah',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3044215257/1513122896',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/940731719149375488/TQppL6_n_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/940731719149375488/TQppL6_n_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'andysnormxn',
#     'statuses_count': 3817,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/CLkGcECqcu',
#     'utc_offset': -28800,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @andysnormxn: So I kinda wanna eat glass #thewalkingdead #carlgrimes https://t.co/gEIy77yuxt',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue May 24 20:11:16 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3635,
#    'follow_request_sent': False,
#    'followers_count': 52,
#    'following': False,
#    'friends_count': 178,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 304608327,
#    'id_str': '304608327',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Oswego NY',
#    'name': 'zara alba sterio',
#    'notifications': False,
#    'profile_background_color': 'C7B0D3',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/530567311/xa6417d05be79fb0b2bf8398f93f4d83.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/530567311/xa6417d05be79fb0b2bf8398f93f4d83.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2291740139/n0rlewyscfdsj30kzstu_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2291740139/n0rlewyscfdsj30kzstu_normal.jpeg',
#    'profile_link_color': 'FFFFFF',
#    'profile_sidebar_border_color': '89C9BD',
#    'profile_sidebar_fill_color': '500875',
#    'profile_text_color': '9966B3',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'zsterio',
#    'statuses_count': 2091,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Dec 16 18:41:37 +0000 2017',
#   'entities': {'hashtags': [{'indices': [20, 36], 'text': 'FlashbackFriday'},
#     {'indices': [37, 52], 'text': 'TheWalkingDead'}],
#    'media': [{'display_url': 'pic.twitter.com/9cV3BgDvA0',
#      'expanded_url': 'https://twitter.com/HershelGreene1/status/941808602519654410/photo/1',
#      'id': 941808596173459456,
#      'id_str': '941808596173459456',
#      'indices': [53, 76],
#      'media_url': 'http://pbs.twimg.com/media/DRH57aVUEAAyK8g.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DRH57aVUEAAyK8g.jpg',
#      'sizes': {'large': {'h': 639, 'resize': 'fit', 'w': 551},
#       'medium': {'h': 639, 'resize': 'fit', 'w': 551},
#       'small': {'h': 639, 'resize': 'fit', 'w': 551},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 941808602519654410,
#      'source_status_id_str': '941808602519654410',
#      'source_user_id': 771041412,
#      'source_user_id_str': '771041412',
#      'type': 'photo',
#      'url': 'https://t.co/9cV3BgDvA0'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 771041412,
#      'id_str': '771041412',
#      'indices': [3, 18],
#      'name': 'Hershel Greene',
#      'screen_name': 'HershelGreene1'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/9cV3BgDvA0',
#      'expanded_url': 'https://twitter.com/HershelGreene1/status/941808602519654410/photo/1',
#      'id': 941808596173459456,
#      'id_str': '941808596173459456',
#      'indices': [53, 76],
#      'media_url': 'http://pbs.twimg.com/media/DRH57aVUEAAyK8g.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DRH57aVUEAAyK8g.jpg',
#      'sizes': {'large': {'h': 639, 'resize': 'fit', 'w': 551},
#       'medium': {'h': 639, 'resize': 'fit', 'w': 551},
#       'small': {'h': 639, 'resize': 'fit', 'w': 551},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 941808602519654410,
#      'source_status_id_str': '941808602519654410',
#      'source_user_id': 771041412,
#      'source_user_id_str': '771041412',
#      'type': 'photo',
#      'url': 'https://t.co/9cV3BgDvA0'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 942102429830733824,
#   'id_str': '942102429830733824',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'und',
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 443,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Dec 15 23:14:03 +0000 2017',
#    'entities': {'hashtags': [{'indices': [0, 16], 'text': 'FlashbackFriday'},
#      {'indices': [17, 32], 'text': 'TheWalkingDead'}],
#     'media': [{'display_url': 'pic.twitter.com/9cV3BgDvA0',
#       'expanded_url': 'https://twitter.com/HershelGreene1/status/941808602519654410/photo/1',
#       'id': 941808596173459456,
#       'id_str': '941808596173459456',
#       'indices': [33, 56],
#       'media_url': 'http://pbs.twimg.com/media/DRH57aVUEAAyK8g.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DRH57aVUEAAyK8g.jpg',
#       'sizes': {'large': {'h': 639, 'resize': 'fit', 'w': 551},
#        'medium': {'h': 639, 'resize': 'fit', 'w': 551},
#        'small': {'h': 639, 'resize': 'fit', 'w': 551},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/9cV3BgDvA0'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/9cV3BgDvA0',
#       'expanded_url': 'https://twitter.com/HershelGreene1/status/941808602519654410/photo/1',
#       'id': 941808596173459456,
#       'id_str': '941808596173459456',
#       'indices': [33, 56],
#       'media_url': 'http://pbs.twimg.com/media/DRH57aVUEAAyK8g.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DRH57aVUEAAyK8g.jpg',
#       'sizes': {'large': {'h': 639, 'resize': 'fit', 'w': 551},
#        'medium': {'h': 639, 'resize': 'fit', 'w': 551},
#        'small': {'h': 639, 'resize': 'fit', 'w': 551},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/9cV3BgDvA0'}]},
#    'favorite_count': 3108,
#    'favorited': False,
#    'geo': None,
#    'id': 941808602519654410,
#    'id_str': '941808602519654410',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'und',
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 443,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': '#FlashbackFriday #TheWalkingDead https://t.co/9cV3BgDvA0',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Aug 21 07:43:07 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Lost my farm, my leg & my head. Now I'm tweeting from the afterlife. This page has no affiliation with AMC or Scott Wilson.(Parody Account)",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'instagram.com/hershelgreene1',
#         'expanded_url': 'http://instagram.com/hershelgreene1',
#         'indices': [0, 22],
#         'url': 'http://t.co/Dzts9YsmHw'}]}},
#     'favourites_count': 57608,
#     'follow_request_sent': False,
#     'followers_count': 245763,
#     'following': False,
#     'friends_count': 176852,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 771041412,
#     'id_str': '771041412',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 398,
#     'location': 'Heaven',
#     'name': 'Hershel Greene',
#     'notifications': False,
#     'profile_background_color': '4A913C',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/637059427149983744/36bNI7HP.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/637059427149983744/36bNI7HP.jpg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/771041412/1402175905',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/416381693629448194/f-a5tqaG_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/416381693629448194/f-a5tqaG_normal.png',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'HershelGreene1',
#     'statuses_count': 18263,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'http://t.co/Dzts9YsmHw',
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @HershelGreene1: #FlashbackFriday #TheWalkingDead https://t.co/9cV3BgDvA0',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Feb 04 18:30:09 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 308,
#    'follow_request_sent': False,
#    'followers_count': 94,
#    'following': False,
#    'friends_count': 199,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 483173918,
#    'id_str': '483173918',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'pt',
#    'listed_count': 1,
#    'location': 'Belém, Brasil',
#    'name': 'correa.y',
#    'notifications': False,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000015158206/97396c04edaf91ee21f1020e3b8a6b13.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000015158206/97396c04edaf91ee21f1020e3b8a6b13.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/483173918/1513086559',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/928045431560470528/Rm7kMgyj_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/928045431560470528/Rm7kMgyj_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '95E8EC',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'yagoccorrea',
#    'statuses_count': 608,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Dec 16 18:41:26 +0000 2017',
#   'entities': {'hashtags': [{'indices': [93, 110], 'text': 'TheWalkingDeadUK'},
#     {'indices': [111, 126], 'text': 'TheWalkingDead'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 836035891168755714,
#      'id_str': '836035891168755714',
#      'indices': [3, 16],
#      'name': 'Ali',
#      'screen_name': 'TvvitterGod1'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 942102386167943168,
#   'id_str': '942102386167943168',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 264,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Dec 11 22:20:13 +0000 2017',
#    'entities': {'hashtags': [{'indices': [75, 92], 'text': 'TheWalkingDeadUK'},
#      {'indices': [93, 108], 'text': 'TheWalkingDead'}],
#     'media': [{'display_url': 'pic.twitter.com/8UP1jNNCwS',
#       'expanded_url': 'https://twitter.com/TvvitterGod1/status/940345504675885056/photo/1',
#       'id': 940345488871776256,
#       'id_str': '940345488871776256',
#       'indices': [109, 132],
#       'media_url': 'http://pbs.twimg.com/media/DQzHPW5X4AAJO22.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DQzHPW5X4AAJO22.jpg',
#       'sizes': {'large': {'h': 1000, 'resize': 'fit', 'w': 1619},
#        'medium': {'h': 741, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 420, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/8UP1jNNCwS'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/8UP1jNNCwS',
#       'expanded_url': 'https://twitter.com/TvvitterGod1/status/940345504675885056/photo/1',
#       'id': 940345488871776256,
#       'id_str': '940345488871776256',
#       'indices': [109, 132],
#       'media_url': 'http://pbs.twimg.com/media/DQzHPW5X4AAJO22.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DQzHPW5X4AAJO22.jpg',
#       'sizes': {'large': {'h': 1000, 'resize': 'fit', 'w': 1619},
#        'medium': {'h': 741, 'resize': 'fit', 'w': 1200},
#        'small': {'h': 420, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/8UP1jNNCwS'}]},
#    'favorite_count': 528,
#    'favorited': False,
#    'geo': None,
#    'id': 940345504675885056,
#    'id_str': '940345504675885056',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 264,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'Carl definitely evolved. Grew to love the kid, it took 8 seasons though I😫 #TheWalkingDeadUK #TheWalkingDead https://t.co/8UP1jNNCwS',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Feb 27 02:11:04 +0000 2017',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Eat, Sleep & Repeat The Process. Daily Struggles. SC- alishah777 👈 🇨🇾',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 104,
#     'follow_request_sent': False,
#     'followers_count': 695,
#     'following': False,
#     'friends_count': 228,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 836035891168755714,
#     'id_str': '836035891168755714',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 48,
#     'location': 'United Kingdom',
#     'name': 'Ali',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/836035891168755714/1512170334',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/936006904207282176/opfStdlt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/936006904207282176/opfStdlt_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'TvvitterGod1',
#     'statuses_count': 1689,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 0,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @TvvitterGod1: Carl definitely evolved. Grew to love the kid, it took 8 seasons though I😫 #TheWalkingDeadUK #TheWalkingDead https://t.co…',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Jun 29 07:18:59 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Author.🃏®|  💲Owner of | GlitterGoon™',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'glittergoon.bigcartel.com',
#        'expanded_url': 'http://www.glittergoon.bigcartel.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/dHPcVCooMV'}]}},
#    'favourites_count': 14710,
#    'follow_request_sent': False,
#    'followers_count': 1783,
#    'following': False,
#    'friends_count': 318,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 51990640,
#    'id_str': '51990640',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 16,
#    'location': 'NYC.  ',
#    'name': 'ANN',
#    'notifications': False,
#    'profile_background_color': '89C9FA',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/790834305/9a1a2e76d5ba83467fa20162a13b0b71.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/790834305/9a1a2e76d5ba83467fa20162a13b0b71.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/51990640/1451439708',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/934298319760838656/-d4SSada_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/934298319760838656/-d4SSada_normal.jpg',
#    'profile_link_color': '7FDBB6',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F9FF9E',
#    'profile_text_color': 'C70C2E',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'chayannedw',
#    'statuses_count': 119680,
#    'time_zone': 'Quito',
#    'translator_type': 'none',
#    'url': 'https://t.co/dHPcVCooMV',
#    'utc_offset': -18000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Dec 16 18:41:25 +0000 2017',
#   'entities': {'hashtags': [{'indices': [89, 97], 'text': 'RIPCarl'},
#     {'indices': [98, 113], 'text': 'TheWalkingDead'}],
#    'media': [{'display_url': 'pic.twitter.com/OtOv74VmLV',
#      'expanded_url': 'https://twitter.com/RickAndThangs/status/940062193042669572/photo/1',
#      'id': 940062184498851841,
#      'id_str': '940062184498851841',
#      'indices': [114, 137],
#      'media_url': 'http://pbs.twimg.com/media/DQvFk33U8AEDX8k.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DQvFk33U8AEDX8k.jpg',
#      'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 675},
#       'medium': {'h': 1024, 'resize': 'fit', 'w': 675},
#       'small': {'h': 680, 'resize': 'fit', 'w': 448},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 940062193042669572,
#      'source_status_id_str': '940062193042669572',
#      'source_user_id': 432832791,
#      'source_user_id_str': '432832791',
#      'type': 'photo',
#      'url': 'https://t.co/OtOv74VmLV'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 432832791,
#      'id_str': '432832791',
#      'indices': [3, 17],
#      'name': 'Rick Grimes',
#      'screen_name': 'RickAndThangs'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/OtOv74VmLV',
#      'expanded_url': 'https://twitter.com/RickAndThangs/status/940062193042669572/photo/1',
#      'id': 940062184498851841,
#      'id_str': '940062184498851841',
#      'indices': [114, 137],
#      'media_url': 'http://pbs.twimg.com/media/DQvFk33U8AEDX8k.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DQvFk33U8AEDX8k.jpg',
#      'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 675},
#       'medium': {'h': 1024, 'resize': 'fit', 'w': 675},
#       'small': {'h': 680, 'resize': 'fit', 'w': 448},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 940062193042669572,
#      'source_status_id_str': '940062193042669572',
#      'source_user_id': 432832791,
#      'source_user_id_str': '432832791',
#      'type': 'photo',
#      'url': 'https://t.co/OtOv74VmLV'},
#     {'display_url': 'pic.twitter.com/OtOv74VmLV',
#      'expanded_url': 'https://twitter.com/RickAndThangs/status/940062193042669572/photo/1',
#      'id': 940062185719414787,
#      'id_str': '940062185719414787',
#      'indices': [114, 137],
#      'media_url': 'http://pbs.twimg.com/media/DQvFk8aVQAMlOKQ.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DQvFk8aVQAMlOKQ.jpg',
#      'sizes': {'large': {'h': 480, 'resize': 'fit', 'w': 720},
#       'medium': {'h': 480, 'resize': 'fit', 'w': 720},
#       'small': {'h': 453, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 940062193042669572,
#      'source_status_id_str': '940062193042669572',
#      'source_user_id': 432832791,
#      'source_user_id_str': '432832791',
#      'type': 'photo',
#      'url': 'https://t.co/OtOv74VmLV'},
#     {'display_url': 'pic.twitter.com/OtOv74VmLV',
#      'expanded_url': 'https://twitter.com/RickAndThangs/status/940062193042669572/photo/1',
#      'id': 940062185702617094,
#      'id_str': '940062185702617094',
#      'indices': [114, 137],
#      'media_url': 'http://pbs.twimg.com/media/DQvFk8WU8AY_dw6.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DQvFk8WU8AY_dw6.jpg',
#      'sizes': {'large': {'h': 1000, 'resize': 'fit', 'w': 700},
#       'medium': {'h': 1000, 'resize': 'fit', 'w': 700},
#       'small': {'h': 680, 'resize': 'fit', 'w': 476},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 940062193042669572,
#      'source_status_id_str': '940062193042669572',
#      'source_user_id': 432832791,
#      'source_user_id_str': '432832791',
#      'type': 'photo',
#      'url': 'https://t.co/OtOv74VmLV'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 942102382195851264,
#   'id_str': '942102382195851264',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 1315,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Dec 11 03:34:26 +0000 2017',
#    'entities': {'hashtags': [{'indices': [70, 78], 'text': 'RIPCarl'},
#      {'indices': [79, 94], 'text': 'TheWalkingDead'}],
#     'media': [{'display_url': 'pic.twitter.com/OtOv74VmLV',
#       'expanded_url': 'https://twitter.com/RickAndThangs/status/940062193042669572/photo/1',
#       'id': 940062184498851841,
#       'id_str': '940062184498851841',
#       'indices': [95, 118],
#       'media_url': 'http://pbs.twimg.com/media/DQvFk33U8AEDX8k.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DQvFk33U8AEDX8k.jpg',
#       'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 675},
#        'medium': {'h': 1024, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 448},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/OtOv74VmLV'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/OtOv74VmLV',
#       'expanded_url': 'https://twitter.com/RickAndThangs/status/940062193042669572/photo/1',
#       'id': 940062184498851841,
#       'id_str': '940062184498851841',
#       'indices': [95, 118],
#       'media_url': 'http://pbs.twimg.com/media/DQvFk33U8AEDX8k.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DQvFk33U8AEDX8k.jpg',
#       'sizes': {'large': {'h': 1024, 'resize': 'fit', 'w': 675},
#        'medium': {'h': 1024, 'resize': 'fit', 'w': 675},
#        'small': {'h': 680, 'resize': 'fit', 'w': 448},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/OtOv74VmLV'},
#      {'display_url': 'pic.twitter.com/OtOv74VmLV',
#       'expanded_url': 'https://twitter.com/RickAndThangs/status/940062193042669572/photo/1',
#       'id': 940062185719414787,
#       'id_str': '940062185719414787',
#       'indices': [95, 118],
#       'media_url': 'http://pbs.twimg.com/media/DQvFk8aVQAMlOKQ.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DQvFk8aVQAMlOKQ.jpg',
#       'sizes': {'large': {'h': 480, 'resize': 'fit', 'w': 720},
#        'medium': {'h': 480, 'resize': 'fit', 'w': 720},
#        'small': {'h': 453, 'resize': 'fit', 'w': 680},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/OtOv74VmLV'},
#      {'display_url': 'pic.twitter.com/OtOv74VmLV',
#       'expanded_url': 'https://twitter.com/RickAndThangs/status/940062193042669572/photo/1',
#       'id': 940062185702617094,
#       'id_str': '940062185702617094',
#       'indices': [95, 118],
#       'media_url': 'http://pbs.twimg.com/media/DQvFk8WU8AY_dw6.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/DQvFk8WU8AY_dw6.jpg',
#       'sizes': {'large': {'h': 1000, 'resize': 'fit', 'w': 700},
#        'medium': {'h': 1000, 'resize': 'fit', 'w': 700},
#        'small': {'h': 680, 'resize': 'fit', 'w': 476},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/OtOv74VmLV'}]},
#    'favorite_count': 3369,
#    'favorited': False,
#    'geo': None,
#    'id': 940062193042669572,
#    'id_str': '940062193042669572',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1315,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'For now, we say goodbye. Rest in peace Carl. We’ll miss you, sheriff. #RIPCarl #TheWalkingDead https://t.co/OtOv74VmLV',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Dec 09 20:51:49 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Tweeting Stuff... Thangs. (Parody)',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 191232,
#     'follow_request_sent': False,
#     'followers_count': 293201,
#     'following': False,
#     'friends_count': 261491,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 432832791,
#     'id_str': '432832791',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 513,
#     'location': 'At war.',
#     'name': 'Rick Grimes',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/492884090622726144/7s6bTa-E.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/492884090622726144/7s6bTa-E.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/432832791/1508845089',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/940256168332500992/alAgxUe2_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/940256168332500992/alAgxUe2_normal.jpg',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'RickAndThangs',
#     'statuses_count': 4240,
#     'time_zone': 'Eastern Time (US & Canada)',
#     'translator_type': 'regular',
#     'url': None,
#     'utc_offset': -18000,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'RT @RickAndThangs: For now, we say goodbye. Rest in peace Carl. We’ll miss you, sheriff. #RIPCarl #TheWalkingDead https://t.co/OtOv74VmLV',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Sep 08 23:11:43 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Sehun of Kai is not a question. Chanbeak. Lumin We Are One E X O 💕(@weareoneEXO) #VOTEforEXOTH #EXO - ปล่อยกูเถอะทวิตกู- #มีตติ้งไคฮุน',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 1096,
#    'follow_request_sent': False,
# ...
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 1026,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Mon Dec 11 04:34:00 +0000 2017',
#    'entities': {'hashtags': [{'indices': [47, 57], 'text': 'luckygirl'},
#      {'indices': [74, 89], 'text': 'TheWalkingDead'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 381688396,
#       'id_str': '381688396',
#       'indices': [30, 45],
#       'name': 'Talking Dead',
#       'screen_name': 'AMCTalkingDead'},
#      {'id': 381688396,
#       'id_str': '381688396',
#       'indices': [58, 73],
#       'name': 'Talking Dead',
#       'screen_name': 'AMCTalkingDead'}]},
#    'favorite_count': 9,
#    'favorited': False,
#    'geo': None,
#    'id': 940077183183101952,
#    'id_str': '940077183183101952',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1026,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'OMG......Mona is too sweet on @AMCTalkingDead. #luckygirl @AMCTalkingDead #TheWalkingDead',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Jan 25 03:36:16 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'I respectfully, color outside the lines, sometimes. Depression does not define me. Need books, writing, music, love, and hugs.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 9197,
#     'follow_request_sent': False,
#     'followers_count': 895,
#     'following': False,
#     'friends_count': 760,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 4810475504,
#     'id_str': '4810475504',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 9,
#     'location': 'Texas',
#     'name': 'Toni Tullos',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4810475504/1478155913',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/846173700282048512/z2Gpnktk_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/846173700282048512/z2Gpnktk_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'toni_tullos',
#     'statuses_count': 4240,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'text': 'RT @toni_tullos: OMG......Mona is too sweet on @AMCTalkingDead. #luckygirl @AMCTalkingDead #TheWalkingDead',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Mar 24 14:43:15 +0000 2013',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'You don’t know about me, but I bet you want to // @alybdygmz👯',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'Instagram.com/sementheeee',
#        'expanded_url': 'http://Instagram.com/sementheeee',
#        'indices': [0, 23],
#        'url': 'https://t.co/9gpeRFsLyE'}]}},
#    'favourites_count': 8823,
#    'follow_request_sent': False,
#    'followers_count': 654,
#    'following': False,
#    'friends_count': 510,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 1295514439,
#    'id_str': '1295514439',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Lyceum',
#    'name': 'marìe🥀',
#    'notifications': False,
#    'profile_background_color': '1D043A',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/545876310719860736/GDxsaQDU.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/545876310719860736/GDxsaQDU.jpeg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1295514439/1508172791',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/939507156205760513/R_zbpnlX_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/939507156205760513/R_zbpnlX_normal.jpg',
#    'profile_link_color': '480D4A',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F77937',
#    'profile_text_color': 'BB1C60',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'sementheee',
#    'statuses_count': 16613,
#    'time_zone': "Nuku'alofa",
#    'translator_type': 'none',
#    'url': 'https://t.co/9gpeRFsLyE',
#    'utc_offset': 50400,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat Dec 16 18:39:18 +0000 2017',
#   'entities': {'hashtags': [{'indices': [66, 81], 'text': 'TheWalkingDead'}],
#    'media': [{'display_url': 'pic.twitter.com/Tpmn8HfwI2',
#      'expanded_url': 'https://twitter.com/negansbby/status/940391581013639168/video/1',
#      'id': 940391408862560256,
#      'id_str': '940391408862560256',
#      'indices': [82, 105],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/940391408862560256/pu/img/Va1zHsNP0B6nc7pi.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/940391408862560256/pu/img/Va1zHsNP0B6nc7pi.jpg',
#      'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 360, 'resize': 'fit', 'w': 640},
#       'small': {'h': 360, 'resize': 'fit', 'w': 640},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 940391581013639168,
#      'source_status_id_str': '940391581013639168',
#      'source_user_id': 817845958696386564,
#      'source_user_id_str': '817845958696386564',
#      'type': 'photo',
#      'url': 'https://t.co/Tpmn8HfwI2'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 4100640581,
#      'id_str': '4100640581',
#      'indices': [3, 13],
#      'name': 'WalkingDeadSquad',
#      'screen_name': 'TWDClique'}]},
#   'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#      'display_url': 'pic.twitter.com/Tpmn8HfwI2',
#      'expanded_url': 'https://twitter.com/negansbby/status/940391581013639168/video/1',
#      'id': 940391408862560256,
#      'id_str': '940391408862560256',
#      'indices': [82, 105],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/940391408862560256/pu/img/Va1zHsNP0B6nc7pi.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/940391408862560256/pu/img/Va1zHsNP0B6nc7pi.jpg',
#      'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#       'medium': {'h': 360, 'resize': 'fit', 'w': 640},
#       'small': {'h': 360, 'resize': 'fit', 'w': 640},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 940391581013639168,
#      'source_status_id_str': '940391581013639168',
#      'source_user_id': 817845958696386564,
#      'source_user_id_str': '817845958696386564',
#      'type': 'video',
#      'url': 'https://t.co/Tpmn8HfwI2',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 1400,
#       'variants': [{'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/940391408862560256/pu/vid/640x360/SOb5hAekUOEZDd6_.mp4'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/940391408862560256/pu/pl/hJUQbTgqX2f198qC.m3u8'},
#        {'bitrate': 320000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/940391408862560256/pu/vid/320x180/w_u19FjMOCkzum0E.mp4'}]}}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 942101848625942530,
#   'id_str': '942101848625942530',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 59,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Dec 13 02:30:14 +0000 2017',
#    'entities': {'hashtags': [{'indices': [51, 66], 'text': 'TheWalkingDead'}],
#     'media': [{'display_url': 'pic.twitter.com/Tpmn8HfwI2',
#       'expanded_url': 'https://twitter.com/negansbby/status/940391581013639168/video/1',
#       'id': 940391408862560256,
#       'id_str': '940391408862560256',
#       'indices': [67, 90],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/940391408862560256/pu/img/Va1zHsNP0B6nc7pi.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/940391408862560256/pu/img/Va1zHsNP0B6nc7pi.jpg',
#       'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 360, 'resize': 'fit', 'w': 640},
#        'small': {'h': 360, 'resize': 'fit', 'w': 640},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 940391581013639168,
#       'source_status_id_str': '940391581013639168',
#       'source_user_id': 817845958696386564,
#       'source_user_id_str': '817845958696386564',
#       'type': 'photo',
#       'url': 'https://t.co/Tpmn8HfwI2'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#       'display_url': 'pic.twitter.com/Tpmn8HfwI2',
#       'expanded_url': 'https://twitter.com/negansbby/status/940391581013639168/video/1',
#       'id': 940391408862560256,
#       'id_str': '940391408862560256',
#       'indices': [67, 90],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/940391408862560256/pu/img/Va1zHsNP0B6nc7pi.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/940391408862560256/pu/img/Va1zHsNP0B6nc7pi.jpg',
#       'sizes': {'large': {'h': 360, 'resize': 'fit', 'w': 640},
#        'medium': {'h': 360, 'resize': 'fit', 'w': 640},
#        'small': {'h': 360, 'resize': 'fit', 'w': 640},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 940391581013639168,
#       'source_status_id_str': '940391581013639168',
#       'source_user_id': 817845958696386564,
#       'source_user_id_str': '817845958696386564',
#       'type': 'video',
#       'url': 'https://t.co/Tpmn8HfwI2',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 1400,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/940391408862560256/pu/vid/640x360/SOb5hAekUOEZDd6_.mp4'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/940391408862560256/pu/pl/hJUQbTgqX2f198qC.m3u8'},
#         {'bitrate': 320000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/940391408862560256/pu/vid/320x180/w_u19FjMOCkzum0E.mp4'}]}}]},
#    'favorite_count': 172,
#    'favorited': False,
#    'geo': None,
#    'id': 940770812197588992,
#    'id_str': '940770812197588992',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 59,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'The Negan lean has been taken to a whole new level #TheWalkingDead https://t.co/Tpmn8HfwI2',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Nov 02 23:33:06 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'The best place for Walking Dead tweets, images, news, humor, and more! #Ricktatorship',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1008,
#     'follow_request_sent': False,
#     'followers_count': 6469,
#     'following': False,
#     'friends_count': 4452,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 4100640581,
#     'id_str': '4100640581',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 38,
#     'location': '',
#     'name': 'WalkingDeadSquad',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4100640581/1446507556',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/661326954885488640/fhZ_uhTV_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/661326954885488640/fhZ_uhTV_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'TWDClique',
#     'statuses_count': 1463,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @TWDClique: The Negan lean has been taken to a whole new level #TheWalkingDead https://t.co/Tpmn8HfwI2',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue May 24 20:11:16 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3635,
#    'follow_request_sent': False,
#    'followers_count': 52,
#    'following': False,
#    'friends_count': 178,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 304608327,
#    'id_str': '304608327',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'Oswego NY',
#    'name': 'zara alba sterio',
#    'notifications': False,
#    'profile_background_color': 'C7B0D3',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/530567311/xa6417d05be79fb0b2bf8398f93f4d83.png',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/530567311/xa6417d05be79fb0b2bf8398f93f4d83.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2291740139/n0rlewyscfdsj30kzstu_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2291740139/n0rlewyscfdsj30kzstu_normal.jpeg',
#    'profile_link_color': 'FFFFFF',
#    'profile_sidebar_border_color': '89C9BD',
#    'profile_sidebar_fill_color': '500875',
#    'profile_text_color': '9966B3',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'zsterio',
#    'statuses_count': 2091,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -18000,
#    'verified': False}}]

# %% [markdown]
# Um zu überprüfen, ob wir die Daten auch mit unseren Methoden, die wir weiter oben benutzt hatten, auswerten können, werden wir dies an zwei Beispielmethoden überprüfen

# %%
twd_status_texts = [ status['text'] for status in twdtweets ]

twd_screen_names = [ user_mention['screen_name'] 
                for status in twdtweets
                    for user_mention in status['entities']['user_mentions']]

twd_hashtags = [ hashtag['text']
               for status in twdtweets
                   for hashtag in status['entities']['hashtags']]

# %%
print(json.dumps(twd_status_texts[0:5], indent=1))
print(json.dumps(twd_screen_names[0:5], indent=1))
print(json.dumps(twd_hashtags[0:5], indent=1))
# Out:
# [
#  "RT @TheWalkingDead: How do you feel about #TheWalkingDead Mid-Season Finale after almost a week? Tell us: https://t.co/rH5Es6uE2X https://t\u2026",
#  "RT @andysnormxn: So I kinda wanna eat glass #thewalkingdead #carlgrimes https://t.co/gEIy77yuxt",
#  "RT @HershelGreene1: #FlashbackFriday #TheWalkingDead https://t.co/9cV3BgDvA0",
#  "RT @TvvitterGod1: Carl definitely evolved. Grew to love the kid, it took 8 seasons though I\ud83d\ude2b #TheWalkingDeadUK #TheWalkingDead https://t.co\u2026",
#  "RT @RickAndThangs: For now, we say goodbye. Rest in peace Carl. We\u2019ll miss you, sheriff. #RIPCarl #TheWalkingDead https://t.co/OtOv74VmLV"
# ]
# [
#  "TheWalkingDead",
#  "andysnormxn",
#  "HershelGreene1",
#  "TvvitterGod1",
#  "RickAndThangs"
# ]
# [
#  "TheWalkingDead",
#  "thewalkingdead",
#  "carlgrimes",
#  "FlashbackFriday",
#  "TheWalkingDead"
# ]

# %%
print('Lexikalische Vielfalt der Usernamen: ', lexical_diversity(twd_screen_names))
print('Lexikalische Vielfalt der Hashtags: ', lexical_diversity(twd_hashtags))
print('Durchschnitt. # der Wörter eines Tweets: ', average_words(twd_status_texts))
# Out:
# Lexikalische Vielfalt der Usernamen:  0.8461538461538461
# Lexikalische Vielfalt der Hashtags:  0.5
# Durchschnitt. # der Wörter eines Tweets:  13.466666666666667

# %% [markdown]
# Wie man sehen kann, klappt dies wunderbar, sodass es sich lohnt, die gesammelten Tweets in eine Datei zu speichern. So könnte man auch gut ein Skript über ein paar Tage laufen lassen, das die Tweets mehrmals pro Tag abfragt und in die Datei speichert, wodurch eine große Menge an Daten zusammenkommen würde.
#
#
#
#
# # Fazit
#
# Twitter ist ein vielfältiges soziales Netzwerk, mit dem man sehr viele umfangreiche Analysen betreiben kann. Auf Grund dessen, dass sich Twitter als Medium so schnell weiter bewegt, können vorallem Analysen zu aktuellen Themen getroffen werden. Es eignet sich also sehr gut, um aktuelle Geschehnisse in der Welt zu bewerten. Dieses Notebook war nur ein kleiner Einschnitt in das Thema Datamining im Bezug auf Twitter.

# %% [markdown]
# # <span style="color:red">Kommentar JI</span>
#
# Das Thema wurde schön und anschaulich dargestellt, hier und da könnte allerdings der Code noch ein bisschen näher erklärt werden, für ein besseres Verständnis. Vorhandene Rechtschreib- und Grammatikfehler, die gefunden wurden, wurden direkt verbessert.
#
# Was mir sehr gut gefällt, ist, dass du das Thema sowohl in Python, als auch in R bearbeitet hast. Die Namen der Notebooks solltest du dahingehend noch anpassen.
#
# Die Übung ist gut gemacht, es wird sowohl Theorie, als auch Anwendung gefragt.
#
# Alles in Allem wirklich sehr schön gemacht!

# %% [markdown]
# # Quellen
#
# Matthew A. Russell - Mining the Social Web
#
# https://de.wikipedia.org/wiki/Programmierschnittstelle
#
# https://www.dev-insider.de/was-ist-eine-api-a-583923/
